# %%
# ================================
# BYOL Step 1: Imports
# ================================
import os, math, time, warnings
from pathlib import Path

import random   
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split

import torchvision
from torchvision import transforms as T, models

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
import plotly.express as px

from contextlib import nullcontext
from torch.amp import GradScaler, autocast  # modern API

# %%
# ============================
# BYOL Step 2: Config & Paths 
# ============================
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# CSVs are inside EuroSAT folder 
CSV_ROOT = "/kaggle/input/eurosat-dataset/EuroSAT"
IMG_ROOT = "/kaggle/input/eurosat-dataset/EuroSAT"

TRAIN_CSV = "train.csv"
VAL_CSV   = "validation.csv"
TEST_CSV  = "test.csv"

IMG_SIZE = 224
BATCH_SIZE_PRETRAIN = 64
EPOCHS_PRETRAIN = 400
LR_PRETRAIN = 3e-4
PROJ_DIM = 128

BATCH_SIZE_LINEAR = 64
EPOCHS_LINEAR = 400
LR_LINEAR = 1e-3

print("Device:", DEVICE)
print(f"Device: {DEVICE.type}")
print(f"IMG_ROOT: {IMG_ROOT}")
print(f"CSV_ROOT: {CSV_ROOT}")
print(f"Splits: {TRAIN_CSV} {VAL_CSV} {TEST_CSV}")
# Out:
# Device: cuda
# Device: cuda
# IMG_ROOT: /kaggle/input/eurosat-dataset/EuroSAT
# CSV_ROOT: /kaggle/input/eurosat-dataset/EuroSAT
# Splits: train.csv validation.csv test.csv

# %%
# =========================
# BYOL Step 3: CSV Loading 
# =========================
def _pick_col(df, candidates):
    lower = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand in df.columns: return cand
        if cand.lower() in lower: return lower[cand.lower()]
    return None

def _fix_one_path(p: str, img_root: str):
    p = str(p).strip()
    if os.path.exists(p): return p
    cand = os.path.join(img_root, p.lstrip("/"))
    if os.path.exists(cand): return cand
    if p.startswith("/kaggle/input/"):
        parts = p.split("/")
        try:
            newp = os.path.join(img_root, "/".join(parts[4:]))
            if os.path.exists(newp): return newp
        except Exception:
            pass
    return cand

def _infer_path_from_parts(row, img_root, filename_col=None, class_col=None):
    fname = str(row[filename_col]).strip() if filename_col else None
    cname = str(row[class_col]).strip() if class_col else None
    cands = []
    if fname:
        cands.append(os.path.join(img_root, fname))
        if class_col:
            cands.append(os.path.join(img_root, cname, fname))
            cands.append(os.path.join(img_root, cname.lower(), fname))
            cands.append(os.path.join(img_root, cname.capitalize(), fname))
    for c in cands:
        if os.path.exists(c): return c
    return cands[0] if cands else None

def load_split(csv_root: str, csv_name: str, img_root: str):
    csv_path = os.path.join(csv_root, csv_name)
    df = pd.read_csv(csv_path)

    if "Unnamed: 0" in df.columns:
        df = df.drop(columns=["Unnamed: 0"])

    path_col     = _pick_col(df, ["path", "filepath", "image", "image_path", "file"])
    filename_col = _pick_col(df, ["filename", "file_name", "image_id"])
    class_col    = _pick_col(df, ["classname", "class_name", "class", "category"])
    label_col    = _pick_col(df, ["label", "labels", "target", "y", "Label"])

    if path_col:
        df["path_fixed"] = df[path_col].apply(lambda p: _fix_one_path(p, img_root))
    elif filename_col:
        df["path_fixed"] = df.apply(lambda r: _infer_path_from_parts(r, img_root, filename_col, class_col), axis=1)
    else:
        raise ValueError(f"No path-like column found. Available: {list(df.columns)}.")

    if label_col is not None:
        if np.issubdtype(df[label_col].dtype, np.number):
            df["label_fixed"] = df[label_col].astype(int)
        else:
            df["label_fixed"] = pd.Categorical(df[label_col]).codes
    elif class_col is not None:
        df["label_fixed"] = pd.Categorical(df[class_col]).codes
    else:
        raise ValueError(f"No label-like column found. Available: {list(df.columns)}.")

    out = df[["path_fixed", "label_fixed"]].rename(columns={"path_fixed":"path","label_fixed":"label"})
    print(out.head())
    return out

# Load with corrected roots
train_df = load_split(CSV_ROOT, TRAIN_CSV, IMG_ROOT)
val_df   = load_split(CSV_ROOT, VAL_CSV,   IMG_ROOT)
test_df  = load_split(CSV_ROOT, TEST_CSV,  IMG_ROOT)

num_classes = int(max(train_df["label"].max(), val_df["label"].max(), test_df["label"].max()) + 1)
print(f"Loaded splits — train: {len(train_df)}, val: {len(val_df)}, test: {len(test_df)}, classes: {num_classes}")
# Out:
#                                                 path  label
# 0  /kaggle/input/eurosat-dataset/EuroSAT/AnnualCr...      0
# 1  /kaggle/input/eurosat-dataset/EuroSAT/Herbaceo...      2
# 2  /kaggle/input/eurosat-dataset/EuroSAT/Permanen...      6
# 3  /kaggle/input/eurosat-dataset/EuroSAT/Industri...      4
# 4  /kaggle/input/eurosat-dataset/EuroSAT/Herbaceo...      2
#                                                 path  label
# 0  /kaggle/input/eurosat-dataset/EuroSAT/Pasture/...      5
# 1  /kaggle/input/eurosat-dataset/EuroSAT/Forest/F...      1
# 2  /kaggle/input/eurosat-dataset/EuroSAT/Highway/...      3
# 3  /kaggle/input/eurosat-dataset/EuroSAT/River/Ri...      8
# 4  /kaggle/input/eurosat-dataset/EuroSAT/SeaLake/...      9
#                                                 path  label
# 0  /kaggle/input/eurosat-dataset/EuroSAT/AnnualCr...      0
# 1  /kaggle/input/eurosat-dataset/EuroSAT/Resident...      7
# 2  /kaggle/input/eurosat-dataset/EuroSAT/Pasture/...      5
# 3  /kaggle/input/eurosat-dataset/EuroSAT/Resident...      7
# 4  /kaggle/input/eurosat-dataset/EuroSAT/Pasture/...      5
# Loaded splits — train: 18900, val: 5400, test: 2700, classes: 10

# %%
# ========================================
# BYOL Step 4: Per-class image count plots
# ========================================
def _counts_bar(vc, title):
    plt.figure()
    xs = list(range(len(vc.index)))
    ys = [int(v) for v in vc.values]
    plt.bar(xs, ys)
    plt.xticks(xs, [str(i) for i in vc.index], rotation=0)
    plt.title(title)
    plt.xlabel("Class label")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

def show_split_counts(train_df, val_df, test_df):
    for name, df in [("Train", train_df), ("Val", val_df), ("Test", test_df)]:
        vc = df["label"].value_counts().sort_index()
        print(f"\n{name} per-class counts (label -> count)")
        for k, v in vc.items():
            print(f"{k}: {v}")
        _counts_bar(vc, f"{name} per-class counts")

show_split_counts(train_df, val_df, test_df)
# Out:
# Train per-class counts (label -> count)
# 0: 2100
# 1: 2100
# 2: 2100
# 3: 1750
# 4: 1750
# 5: 1400
# 6: 1750
# 7: 2100
# 8: 1750
# 9: 2100
# Val per-class counts (label -> count)
# 0: 600
# 1: 600
# 2: 600
# 3: 500
# 4: 500
# 5: 400
# 6: 500
# 7: 600
# 8: 500
# 9: 600
# Test per-class counts (label -> count)
# 0: 300
# 1: 300
# 2: 300
# 3: 250
# 4: 250
# 5: 200
# 6: 250
# 7: 300
# 8: 250
# 9: 300

# %%
# --- Augmentations for BYOL (two views of the same image) ---
class TransformBYOL:
    def __init__(self, size=IMG_SIZE):
        self.base = T.Compose([
            T.RandomResizedCrop(size=size, scale=(0.2, 1.0)),
            T.RandomHorizontalFlip(p=0.5),
            T.RandomApply([T.ColorJitter(0.4, 0.4, 0.2, 0.1)], p=0.8),
            T.RandomGrayscale(p=0.2),
            T.RandomApply([T.GaussianBlur(kernel_size=3)], p=0.5),
            T.ToTensor(),
            T.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225]),
        ])

    def __call__(self, x):
        # two independently augmented views
        q = self.base(x)
        k = self.base(x)
        return q, k

# Single-view transform (for linear eval features/classification)
class SingleTransform:
    def __init__(self, size=IMG_SIZE):
        self.t = T.Compose([
            T.Resize(int(size*1.14)),
            T.CenterCrop(size),
            T.ToTensor(),
            T.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225]),
        ])
    def __call__(self, x):
        return self.t(x)

# --- Datasets ---
class PairDataset(torch.utils.data.Dataset):
    """Returns two augmented views of the same image (BYOL pretraining)."""
    def __init__(self, df, transform_pair: TransformBYOL):
        self.df = df.reset_index(drop=True)
        self.transform_pair = transform_pair

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        p = self.df.loc[idx, "path"]
        img = Image.open(p).convert("RGB")
        v1, v2 = self.transform_pair(img)
        return v1, v2

class ClassifyDataset(torch.utils.data.Dataset):
    """Single view + label (for linear eval)."""
    def __init__(self, df, transform: SingleTransform):
        self.df = df.reset_index(drop=True)
        self.t = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        p  = self.df.loc[idx, "path"]
        y  = int(self.df.loc[idx, "label"])
        img = Image.open(p).convert("RGB")
        x = self.t(img)
        return x, y

# %%
# ===================================
# BYOL Step 6: Dataloaders (Optimized)
# ===================================
pair_tf   = TransformBYOL(IMG_SIZE)
single_tf = SingleTransform(IMG_SIZE)

train_pair_ds = PairDataset(train_df, pair_tf)
val_pair_ds   = PairDataset(val_df,   pair_tf)

train_pair_loader = DataLoader(
    train_pair_ds,
    batch_size=BATCH_SIZE_PRETRAIN,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True,
    prefetch_factor=4
)

val_pair_loader = DataLoader(
    val_pair_ds,
    batch_size=BATCH_SIZE_PRETRAIN,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True,
    prefetch_factor=4
)

train_cls_ds = ClassifyDataset(train_df, single_tf)
val_cls_ds   = ClassifyDataset(val_df,   single_tf)
test_cls_ds  = ClassifyDataset(test_df,  single_tf)

train_cls_loader = DataLoader(
    train_cls_ds,
    batch_size=BATCH_SIZE_LINEAR,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=4
)

val_cls_loader = DataLoader(
    val_cls_ds,
    batch_size=BATCH_SIZE_LINEAR,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=4
)

test_cls_loader = DataLoader(
    test_cls_ds,
    batch_size=BATCH_SIZE_LINEAR,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=4
)

print("PairDataset length:", len(train_pair_ds))
print("ClassifyDataset length:", len(train_cls_ds))
# Out:
# PairDataset length: 18900
# ClassifyDataset length: 18900

# %%
# =================================================================
# BYOL Step 7: Model (Encoder + Projection/Prediction + Target EMA)
# =================================================================
from copy import deepcopy

# --- Encoder (ResNet-50 backbone without final FC) ---
def build_encoder(pretrained: bool = False):
    enc = models.resnet50(weights=None if not pretrained else models.ResNet50_Weights.IMAGENET1K_V2)
    feat_dim = enc.fc.in_features
    enc.fc = nn.Identity()
    return enc, feat_dim

# --- Small helpers ---
class L2Norm(nn.Module):
    def __init__(self, dim=1, eps=1e-8):
        super().__init__()
        self.dim = dim
        self.eps = eps
    def forward(self, x):
        return F.normalize(x, dim=self.dim, eps=self.eps)

# --- Projection MLP (BYOL) ---
class ProjectionHead(nn.Module):
    def __init__(self, in_dim, proj_dim=PROJ_DIM, hidden_dim=None):
        super().__init__()
        h = hidden_dim or in_dim
        self.net = nn.Sequential(
            nn.Linear(in_dim, h, bias=False),
            nn.BatchNorm1d(h),
            nn.ReLU(inplace=True),
            nn.Linear(h, proj_dim, bias=False),
            nn.BatchNorm1d(proj_dim, affine=False),  
        )
        self.norm = L2Norm(dim=1)
    def forward(self, x):
        z = self.net(x)
        return self.norm(z)

# --- Prediction MLP (BYOL) ---
class PredictionHead(nn.Module):
    def __init__(self, in_dim=PROJ_DIM, hidden_dim=None, out_dim=PROJ_DIM):
        super().__init__()
        h = hidden_dim or max(128, in_dim // 2)
        self.net = nn.Sequential(
            nn.Linear(in_dim, h, bias=False),
            nn.BatchNorm1d(h),
            nn.ReLU(inplace=True),
            nn.Linear(h, out_dim)
        )
        self.norm = L2Norm(dim=1)
    def forward(self, z):
        p = self.net(z)
        return self.norm(p)

# --- BYOL Online / Target Wrappers ---
class OnlineNet(nn.Module):
    def __init__(self, encoder, feat_dim, proj_dim=PROJ_DIM):
        super().__init__()
        self.encoder = encoder
        self.projector = ProjectionHead(feat_dim, proj_dim=proj_dim)
        self.predictor = PredictionHead(in_dim=proj_dim, out_dim=proj_dim)
    def forward(self, x):
        h = self.encoder(x)           # [B, feat_dim]
        z = self.projector(h)         # [B, proj_dim] (normalized)
        p = self.predictor(z)         # [B, proj_dim] (normalized)
        return p, z

class TargetNet(nn.Module):
    def __init__(self, encoder, feat_dim, proj_dim=PROJ_DIM):
        super().__init__()
        self.encoder = encoder
        self.projector = ProjectionHead(feat_dim, proj_dim=proj_dim)
        # target has no predictor; it supplies stop-grad "z"
        for p in self.parameters():
            p.requires_grad = False
    @torch.no_grad()
    def forward(self, x):
        h = self.encoder(x)
        z = self.projector(h)
        return z

# --- EMA utilities ---
@torch.no_grad()
def copy_params(src: nn.Module, dst: nn.Module):
    for p_s, p_d in zip(src.parameters(), dst.parameters()):
        p_d.data.copy_(p_s.data)

@torch.no_grad()
def momentum_update(target: nn.Module, online: nn.Module, m: float = 0.996):
    for p_t, p_o in zip(target.parameters(), online.parameters()):
        p_t.data = p_t.data * m + p_o.data * (1.0 - m)

# --- BYOL loss (symmetric cosine) ---
def byol_loss(p, z):
    # p, z are L2-normalized; stop-grad should be applied to z before calling this
    return 2 - 2 * F.cosine_similarity(p, z, dim=1).mean()

# --- Full BYOL module (manages online/target, forward computes loss) ---
class BYOL(nn.Module):
    def __init__(self, proj_dim=PROJ_DIM, momentum=0.996, pretrained_backbone=False):
        super().__init__()
        self.m = momentum

        # build online & target encoders
        enc_online, feat_dim = build_encoder(pretrained=pretrained_backbone)
        enc_target, _        = build_encoder(pretrained=pretrained_backbone)

        self.online  = OnlineNet(enc_online, feat_dim, proj_dim=proj_dim)
        self.target  = TargetNet(enc_target, feat_dim, proj_dim=proj_dim)

        # init target = online
        copy_params(self.online.encoder,   self.target.encoder)
        copy_params(self.online.projector, self.target.projector)

    @torch.no_grad()
    def update_target(self):
        momentum_update(self.target.encoder,   self.online.encoder,   m=self.m)
        momentum_update(self.target.projector, self.online.projector, m=self.m)

    def forward(self, x1, x2):
        # online predictions
        p1, z1_online = self.online(x1)
        p2, z2_online = self.online(x2)

        # target projections (stop-grad implicitly via nn.Module no-grad usage)
        with torch.no_grad():
            z1 = self.target(x1)
            z2 = self.target(x2)

        # symmetric BYOL loss
        loss = byol_loss(p1, z2.detach()) + byol_loss(p2, z1.detach())
        return loss, (p1, z1_online, p2, z2_online)

# %%
# Turn ON only when you want a fresh start for the *working* dir
os.environ["CLEAR_PRETRAIN"] = "1"   

import os
from pathlib import Path

CLEAR_PRETRAIN = bool(int(os.environ.get("CLEAR_PRETRAIN", "0")))

if CLEAR_PRETRAIN:
    CKPT_SAVE_DIR = Path("/kaggle/working/byol_ckpts")
    for p in [
        CKPT_SAVE_DIR / "byol_pretrain_last.pth",
        CKPT_SAVE_DIR / "byol_pretrain_best_full.pth",
        CKPT_SAVE_DIR / "byol_encoder_best.pth",
    ]:
        try:
            p.unlink()
            print(f"Deleted: {p}")
        except FileNotFoundError:
            pass
        except PermissionError:
            print(f"Cannot delete (read-only?): {p}")
else:
    print("Cleanup skipped (CLEAR_PRETRAIN=0).")

# %%
warnings.filterwarnings("ignore", message=r".*lr_scheduler\.step.*optimizer\.step.*")

# --- knobs (use existing if already set) ---
LR = LR_PRETRAIN
WARMUP_FRAC = WARMUP_FRAC if 'WARMUP_FRAC' in globals() else 0.10
M_BASE  = M_BASE  if 'M_BASE'  in globals() else 0.996
M_FINAL = M_FINAL if 'M_FINAL' in globals() else 0.999
WEIGHT_DECAY = WEIGHT_DECAY if 'WEIGHT_DECAY' in globals() else 1e-4
VAL_EVERY = 2

# --- checkpoint paths (INPUT dataset) ---
CKPT_LOAD_DIR = Path("/kaggle/input/byol-ckpts-4")

# expected at root
LAST_PRE_PATH_LOAD      = str(CKPT_LOAD_DIR / "byol_pretrain_last.pth")
BEST_PRETRAIN_FULL_LOAD = str(CKPT_LOAD_DIR / "byol_pretrain_best_full.pth")

# if not at root, try to find in subfolders
if not (os.path.exists(LAST_PRE_PATH_LOAD) or os.path.exists(BEST_PRETRAIN_FULL_LOAD)):
    last_candidates = list(CKPT_LOAD_DIR.rglob("byol_pretrain_last.pth"))
    best_candidates = list(CKPT_LOAD_DIR.rglob("byol_pretrain_best_full.pth"))
    if last_candidates:
        LAST_PRE_PATH_LOAD = str(last_candidates[0])
    if best_candidates:
        BEST_PRETRAIN_FULL_LOAD = str(best_candidates[0])

# --- save paths (WORKING dir) ---
CKPT_SAVE_DIR = Path("/kaggle/working/byol_ckpts"); CKPT_SAVE_DIR.mkdir(parents=True, exist_ok=True)
BEST_ENC_PATH           = str(CKPT_SAVE_DIR / "byol_encoder_best.pth")
BEST_PRETRAIN_FULL_PATH = str(CKPT_SAVE_DIR / "byol_pretrain_best_full.pth")
LAST_PRE_PATH_SAVE      = str(CKPT_SAVE_DIR / "byol_pretrain_last.pth")

# allow resume (do not override this to 0 in cleanup)
RESUME_PRETRAIN = bool(int(os.environ.get("RESUME_PRETRAIN", "1")))

# --- build model & optimizer (BYOL defined in Step 7) ---
proj_dim = PROJ_DIM if 'PROJ_DIM' in globals() else PROJECTION_DIM
byol = BYOL(proj_dim=proj_dim, momentum=M_BASE, pretrained_backbone=False).to(DEVICE)
opt  = optim.AdamW((p for p in byol.parameters() if p.requires_grad), lr=LR, weight_decay=WEIGHT_DECAY)

# --- cosine LR with warmup (per-step) ---
steps_per_epoch = max(1, len(train_pair_loader))
TOTAL_STEPS  = EPOCHS_PRETRAIN * steps_per_epoch
WARMUP_STEPS = max(1, int(WARMUP_FRAC * TOTAL_STEPS))
def lr_lambda(step):
    if step < WARMUP_STEPS:
        return (step + 1) / float(WARMUP_STEPS)
    t = (step - WARMUP_STEPS) / max(1, (TOTAL_STEPS - WARMUP_STEPS))
    return 0.5 * (1.0 + math.cos(math.pi * t))
scheduler = optim.lr_scheduler.LambdaLR(opt, lr_lambda=lr_lambda)

# --- EMA momentum schedule ---
def ema_m(step):
    t = min(1.0, step / max(1, TOTAL_STEPS))
    return M_BASE + (M_FINAL - M_BASE) * (0.5 * (1.0 + math.cos(math.pi * (1.0 - t))))

# --- AMP ---
USE_AMP = (DEVICE.type == "cuda")
scaler  = GradScaler("cuda", enabled=USE_AMP) if USE_AMP else GradScaler(enabled=False)

# --- bookkeeping / resume ---
hist = {"epoch": [], "train_loss": [], "val_loss": []}
best_val = float("inf"); start_epoch = 1; global_step = 0

def _resume_from(path, tag):
    global hist, best_val, start_epoch, global_step
    ck = torch.load(path, map_location="cpu")
    byol.load_state_dict(ck["model"]); opt.load_state_dict(ck["optimizer"])
    if "scheduler" in ck: scheduler.load_state_dict(ck["scheduler"])
    hist = ck.get("hist", hist); best_val = ck.get("best_val", best_val)
    start_epoch = ck.get("epoch", 0) + 1; global_step = ck.get("global_step", 0)
    print(f"✅ Resumed BYOL from {tag} (epoch {start_epoch}, global_step={global_step})")

if RESUME_PRETRAIN and os.path.exists(LAST_PRE_PATH_LOAD):
    _resume_from(LAST_PRE_PATH_LOAD, "INPUT LAST")
elif RESUME_PRETRAIN and os.path.exists(BEST_PRETRAIN_FULL_LOAD):
    _resume_from(BEST_PRETRAIN_FULL_LOAD, "INPUT BEST")
else:
    print("🚀 Starting BYOL training fresh (no INPUT checkpoint or resume disabled)")

# --- training loop helpers ---
def run_epoch(loader, train=True, epoch_idx=1):
    global global_step
    byol.train(mode=train)
    total, n = 0.0, 0
    for (x1, x2) in loader:
        x1 = x1.to(DEVICE, non_blocking=True); x2 = x2.to(DEVICE, non_blocking=True)
        ctx = autocast("cuda", dtype=torch.float16) if USE_AMP else nullcontext()
        if train:
            opt.zero_grad(set_to_none=True)
            with ctx:
                loss, _ = byol(x1, x2)
            scaler.scale(loss).backward()
            torch.nn.utils.clip_grad_norm_(byol.parameters(), max_norm=1.0)
            scaler.step(opt); scaler.update()
            scheduler.step()
            byol.m = ema_m(global_step); byol.update_target()
            global_step += 1
        else:
            with torch.no_grad(), ctx:
                loss, _ = byol(x1, x2)
        bs = x1.size(0); total += float(loss.item()) * bs; n += bs
    return total / max(1, n)

# --- training ---
for epoch in range(start_epoch, EPOCHS_PRETRAIN + 1):
    t0 = time.time()
    train_loss = run_epoch(train_pair_loader, train=True,  epoch_idx=epoch)
    val_loss   = run_epoch(val_pair_loader,   train=False, epoch_idx=epoch) if (epoch % VAL_EVERY == 0) else float("nan")

    hist["epoch"].append(epoch); hist["train_loss"].append(train_loss); hist["val_loss"].append(val_loss)

    cur_lr = float(opt.param_groups[0]["lr"]); cur_m = float(byol.m)

    # Save BEST (only when val ran)
    if not math.isnan(val_loss) and val_loss < best_val - 1e-6:
        best_val = val_loss
        torch.save({"online_encoder": byol.online.encoder.state_dict(),
                    "online_projector": byol.online.projector.state_dict(),
                    "epoch": epoch, "best_val": best_val}, BEST_ENC_PATH)
        torch.save({"model": byol.state_dict(), "optimizer": opt.state_dict(),
                    "scheduler": scheduler.state_dict(), "hist": hist,
                    "epoch": epoch, "best_val": best_val,
                    "global_step": global_step}, BEST_PRETRAIN_FULL_PATH)
        print(f"✅ Saved BEST (epoch={epoch})")

    # Always save LAST
    torch.save({"model": byol.state_dict(), "optimizer": opt.state_dict(),
                "scheduler": scheduler.state_dict(), "hist": hist,
                "epoch": epoch, "best_val": best_val,
                "global_step": global_step}, LAST_PRE_PATH_SAVE)

    print(f"[epoch {epoch:03d}] train_loss={train_loss:.4f} "
          f"val_loss={val_loss:.4f} lr={cur_lr:.8f} m={cur_m:.6f} "
          f"({time.time() - t0:.1f}s)")
# Out:
# ✅ Resumed BYOL from INPUT LAST (epoch 301, global_step=88500)
# [epoch 301] train_loss=0.1659 val_loss=nan lr=0.00005258 m=0.998569 (215.0s)
# [epoch 302] train_loss=0.1685 val_loss=0.1621 lr=0.00005159 m=0.998577 (257.9s)
# [epoch 303] train_loss=0.1686 val_loss=nan lr=0.00005061 m=0.998585 (212.0s)
# [epoch 304] train_loss=0.1685 val_loss=0.1612 lr=0.00004963 m=0.998593 (252.9s)
# [epoch 305] train_loss=0.1658 val_loss=nan lr=0.00004866 m=0.998601 (211.7s)
# [epoch 306] train_loss=0.1677 val_loss=0.1609 lr=0.00004770 m=0.998609 (253.3s)
# [epoch 307] train_loss=0.1664 val_loss=nan lr=0.00004675 m=0.998617 (212.2s)
# [epoch 308] train_loss=0.1705 val_loss=0.1627 lr=0.00004580 m=0.998625 (253.6s)
# [epoch 309] train_loss=0.1671 val_loss=nan lr=0.00004486 m=0.998633 (211.9s)
# [epoch 310] train_loss=0.1717 val_loss=0.1641 lr=0.00004393 m=0.998641 (252.4s)
# [epoch 311] train_loss=0.1704 val_loss=nan lr=0.00004301 m=0.998648 (212.1s)
# [epoch 312] train_loss=0.1723 val_loss=0.1716 lr=0.00004210 m=0.998656 (254.6s)
# [epoch 313] train_loss=0.1699 val_loss=nan lr=0.00004119 m=0.998663 (212.1s)
# [epoch 314] train_loss=0.1664 val_loss=0.1616 lr=0.00004030 m=0.998671 (253.7s)
# [epoch 315] train_loss=0.1629 val_loss=nan lr=0.00003941 m=0.998678 (212.2s)
# [epoch 316] train_loss=0.1653 val_loss=0.1653 lr=0.00003853 m=0.998685 (254.2s)
# [epoch 317] train_loss=0.1666 val_loss=nan lr=0.00003766 m=0.998692 (212.3s)
# [epoch 318] train_loss=0.1650 val_loss=0.1633 lr=0.00003679 m=0.998700 (253.9s)
# [epoch 319] train_loss=0.1663 val_loss=nan lr=0.00003594 m=0.998707 (212.4s)
# ✅ Saved BEST (epoch=320)
# [epoch 320] train_loss=0.1618 val_loss=0.1582 lr=0.00003509 m=0.998714 (255.2s)
# [epoch 321] train_loss=0.1668 val_loss=nan lr=0.00003426 m=0.998720 (212.4s)
# [epoch 322] train_loss=0.1665 val_loss=0.1613 lr=0.00003343 m=0.998727 (252.5s)
# [epoch 323] train_loss=0.1638 val_loss=nan lr=0.00003261 m=0.998734 (211.8s)
# [epoch 324] train_loss=0.1652 val_loss=0.1600 lr=0.00003180 m=0.998741 (254.3s)
# [epoch 325] train_loss=0.1630 val_loss=nan lr=0.00003100 m=0.998747 (212.1s)
# [epoch 326] train_loss=0.1650 val_loss=0.1606 lr=0.00003020 m=0.998754 (252.7s)
# [epoch 327] train_loss=0.1645 val_loss=nan lr=0.00002942 m=0.998760 (212.0s)
# [epoch 328] train_loss=0.1679 val_loss=0.1623 lr=0.00002865 m=0.998766 (252.6s)
# [epoch 329] train_loss=0.1661 val_loss=nan lr=0.00002788 m=0.998773 (211.8s)
# [epoch 330] train_loss=0.1659 val_loss=0.1610 lr=0.00002713 m=0.998779 (253.5s)
# [epoch 331] train_loss=0.1660 val_loss=nan lr=0.00002638 m=0.998785 (211.8s)
# [epoch 332] train_loss=0.1641 val_loss=0.1679 lr=0.00002564 m=0.998791 (253.5s)
# [epoch 333] train_loss=0.1664 val_loss=nan lr=0.00002492 m=0.998797 (211.8s)
# [epoch 334] train_loss=0.1627 val_loss=0.1685 lr=0.00002420 m=0.998803 (252.4s)
# [epoch 335] train_loss=0.1681 val_loss=nan lr=0.00002349 m=0.998809 (211.6s)
# [epoch 336] train_loss=0.1650 val_loss=0.1614 lr=0.00002279 m=0.998814 (253.5s)
# [epoch 337] train_loss=0.1660 val_loss=nan lr=0.00002210 m=0.998820 (211.9s)
# [epoch 338] train_loss=0.1630 val_loss=0.1611 lr=0.00002142 m=0.998826 (252.5s)
# [epoch 339] train_loss=0.1626 val_loss=nan lr=0.00002076 m=0.998831 (212.0s)
# [epoch 340] train_loss=0.1621 val_loss=0.1630 lr=0.00002010 m=0.998836 (253.0s)
# [epoch 341] train_loss=0.1639 val_loss=nan lr=0.00001945 m=0.998842 (212.0s)
# [epoch 342] train_loss=0.1628 val_loss=0.1589 lr=0.00001881 m=0.998847 (255.8s)
# [epoch 343] train_loss=0.1656 val_loss=nan lr=0.00001818 m=0.998852 (212.3s)
# [epoch 344] train_loss=0.1656 val_loss=0.1654 lr=0.00001756 m=0.998857 (253.2s)
# [epoch 345] train_loss=0.1653 val_loss=nan lr=0.00001695 m=0.998862 (211.6s)
# ✅ Saved BEST (epoch=346)
# [epoch 346] train_loss=0.1632 val_loss=0.1557 lr=0.00001635 m=0.998867 (254.7s)
# [epoch 347] train_loss=0.1674 val_loss=nan lr=0.00001576 m=0.998872 (212.0s)
# [epoch 348] train_loss=0.1650 val_loss=0.1598 lr=0.00001518 m=0.998877 (253.2s)
# [epoch 349] train_loss=0.1676 val_loss=nan lr=0.00001461 m=0.998881 (212.0s)
# [epoch 350] train_loss=0.1671 val_loss=0.1621 lr=0.00001405 m=0.998886 (254.3s)
# [epoch 351] train_loss=0.1616 val_loss=nan lr=0.00001351 m=0.998890 (212.3s)
# [epoch 352] train_loss=0.1626 val_loss=0.1559 lr=0.00001297 m=0.998895 (253.1s)
# [epoch 353] train_loss=0.1662 val_loss=nan lr=0.00001244 m=0.998899 (212.3s)
# [epoch 354] train_loss=0.1619 val_loss=0.1582 lr=0.00001192 m=0.998903 (252.8s)
# [epoch 355] train_loss=0.1631 val_loss=nan lr=0.00001142 m=0.998907 (211.7s)
# [epoch 356] train_loss=0.1618 val_loss=0.1589 lr=0.00001092 m=0.998911 (254.8s)
# [epoch 357] train_loss=0.1651 val_loss=nan lr=0.00001044 m=0.998915 (212.2s)
# [epoch 358] train_loss=0.1595 val_loss=0.1586 lr=0.00000996 m=0.998919 (253.2s)
# [epoch 359] train_loss=0.1616 val_loss=nan lr=0.00000950 m=0.998923 (211.8s)
# [epoch 360] train_loss=0.1605 val_loss=0.1606 lr=0.00000905 m=0.998927 (254.1s)
# [epoch 361] train_loss=0.1626 val_loss=nan lr=0.00000860 m=0.998930 (212.2s)
# [epoch 362] train_loss=0.1624 val_loss=0.1575 lr=0.00000817 m=0.998934 (255.0s)
# [epoch 363] train_loss=0.1633 val_loss=nan lr=0.00000775 m=0.998937 (212.3s)
# [epoch 364] train_loss=0.1649 val_loss=0.1677 lr=0.00000734 m=0.998940 (253.8s)
# [epoch 365] train_loss=0.1629 val_loss=nan lr=0.00000694 m=0.998944 (212.2s)
# [epoch 366] train_loss=0.1665 val_loss=0.1613 lr=0.00000655 m=0.998947 (252.8s)
# [epoch 367] train_loss=0.1617 val_loss=nan lr=0.00000618 m=0.998950 (211.8s)
# ✅ Saved BEST (epoch=368)
# [epoch 368] train_loss=0.1633 val_loss=0.1545 lr=0.00000581 m=0.998953 (254.5s)
# [epoch 369] train_loss=0.1609 val_loss=nan lr=0.00000546 m=0.998956 (212.3s)
# [epoch 370] train_loss=0.1657 val_loss=0.1624 lr=0.00000511 m=0.998959 (253.1s)
# [epoch 371] train_loss=0.1612 val_loss=nan lr=0.00000478 m=0.998961 (211.8s)
# [epoch 372] train_loss=0.1654 val_loss=0.1574 lr=0.00000446 m=0.998964 (253.2s)
# [epoch 373] train_loss=0.1663 val_loss=nan lr=0.00000414 m=0.998966 (211.9s)
# [epoch 374] train_loss=0.1656 val_loss=0.1578 lr=0.00000384 m=0.998969 (252.9s)
# [epoch 375] train_loss=0.1657 val_loss=nan lr=0.00000356 m=0.998971 (211.8s)
# [epoch 376] train_loss=0.1665 val_loss=0.1573 lr=0.00000328 m=0.998973 (253.1s)
# [epoch 377] train_loss=0.1652 val_loss=nan lr=0.00000301 m=0.998976 (211.8s)
# [epoch 378] train_loss=0.1656 val_loss=0.1592 lr=0.00000276 m=0.998978 (253.2s)
# [epoch 379] train_loss=0.1679 val_loss=nan lr=0.00000251 m=0.998980 (212.0s)
# [epoch 380] train_loss=0.1623 val_loss=0.1551 lr=0.00000228 m=0.998982 (253.7s)
# [epoch 381] train_loss=0.1619 val_loss=nan lr=0.00000206 m=0.998983 (212.4s)
# [epoch 382] train_loss=0.1638 val_loss=0.1557 lr=0.00000185 m=0.998985 (257.1s)
# [epoch 383] train_loss=0.1650 val_loss=nan lr=0.00000165 m=0.998987 (212.9s)
# [epoch 384] train_loss=0.1641 val_loss=0.1555 lr=0.00000146 m=0.998988 (256.7s)
# [epoch 385] train_loss=0.1656 val_loss=nan lr=0.00000128 m=0.998990 (212.5s)
# [epoch 386] train_loss=0.1641 val_loss=0.1632 lr=0.00000112 m=0.998991 (256.4s)
# [epoch 387] train_loss=0.1636 val_loss=nan lr=0.00000096 m=0.998992 (212.7s)
# [epoch 388] train_loss=0.1634 val_loss=0.1624 lr=0.00000082 m=0.998993 (256.6s)
# [epoch 389] train_loss=0.1619 val_loss=nan lr=0.00000069 m=0.998994 (212.7s)
# [epoch 390] train_loss=0.1645 val_loss=0.1552 lr=0.00000057 m=0.998995 (253.0s)
# [epoch 391] train_loss=0.1635 val_loss=nan lr=0.00000046 m=0.998996 (211.8s)
# [epoch 392] train_loss=0.1624 val_loss=0.1624 lr=0.00000037 m=0.998997 (253.0s)
# [epoch 393] train_loss=0.1609 val_loss=nan lr=0.00000028 m=0.998998 (212.3s)
# [epoch 394] train_loss=0.1626 val_loss=0.1547 lr=0.00000021 m=0.998998 (254.2s)
# [epoch 395] train_loss=0.1601 val_loss=nan lr=0.00000014 m=0.998999 (212.1s)
# [epoch 396] train_loss=0.1618 val_loss=0.1601 lr=0.00000009 m=0.998999 (253.8s)
# [epoch 397] train_loss=0.1597 val_loss=nan lr=0.00000005 m=0.999000 (212.2s)
# [epoch 398] train_loss=0.1588 val_loss=0.1566 lr=0.00000002 m=0.999000 (253.5s)
# [epoch 399] train_loss=0.1570 val_loss=nan lr=0.00000001 m=0.999000 (212.2s)
# ✅ Saved BEST (epoch=400)
# [epoch 400] train_loss=0.1638 val_loss=0.1544 lr=0.00000000 m=0.999000 (256.6s)

# %%
print("=== BYOL Resume Debug Info ===")
print("RESUME_PRETRAIN =", RESUME_PRETRAIN)
print("start_epoch     =", start_epoch)
print("best_val        =", best_val)
print("hist_len        =", len(hist.get('epoch', [])))
# Out:
# === BYOL Resume Debug Info ===
# RESUME_PRETRAIN = True
# start_epoch     = 301
# best_val        = 0.15443123380343118
# hist_len        = 400

# %%
ep = np.array(hist["epoch"], dtype=int)
tr = np.array(hist["train_loss"], dtype=float)
va = np.array(hist["val_loss"], dtype=float)

plt.figure(figsize=(7,4))
plt.plot(ep, tr, label="Train")
if np.isfinite(va).any():
    m = np.isfinite(va)
    plt.plot(ep[m], va[m], label="Val")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Train 

BEST_ENC_PATH  = "/kaggle/working/byol_ckpts/byol_encoder_best.pth"   # from Step 8
BEST_HEAD_PATH = "/kaggle/working/byol_ckpts/byol_linear_head_best.pth"

# ---- build the same backbone used for BYOL encoder (ResNet-50 features) ----
def build_encoder(pretrained=False):
    backbone = torchvision.models.resnet50(
        weights=None if not pretrained else torchvision.models.ResNet50_Weights.IMAGENET1K_V2
    )
    backbone.fc = nn.Identity()   # 2048-dim features
    FEAT_DIM = 2048
    return backbone, FEAT_DIM

# ---- rebuild encoder & load BYOL-pretrained weights, then freeze ----
encoder, FEAT_DIM = build_encoder(pretrained=False)
ck = torch.load(BEST_ENC_PATH, map_location="cpu")
missing = encoder.load_state_dict(ck["online_encoder"], strict=False)
print("Encoder load (missing/unexpected):", missing)

encoder = encoder.to(DEVICE).eval()
for p in encoder.parameters():
    p.requires_grad = False

# ---- linear head ----
num_classes = int(max(train_df["label"].max(), val_df["label"].max(), test_df["label"].max()) + 1)

class LinearHead(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.fc = nn.Linear(in_dim, out_dim)
    def forward(self, x):
        return self.fc(x)

head = LinearHead(FEAT_DIM, num_classes).to(DEVICE)
opt_lin = optim.Adam(head.parameters(), lr=LR_LINEAR)
crit = nn.CrossEntropyLoss()

# ---- history containers ----
lin_hist = {"epoch": [], "train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

# ---- one epoch (train/eval) ----
def linear_epoch(encoder, loader, train=True):
    head.train(mode=train)
    total_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(DEVICE, non_blocking=True), y.to(DEVICE, non_blocking=True)
        with torch.no_grad():
            feats = encoder(x)                 # [B, 2048]
        logits = head(feats)
        loss = crit(logits, y)

        if train:
            opt_lin.zero_grad(set_to_none=True)
            loss.backward()
            opt_lin.step()

        total_loss += loss.item() * x.size(0)
        pred = logits.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return total_loss / max(1,total), correct / max(1,total)

# ----train linear head ----
best_val_acc = 0.0
for ep in range(1, EPOCHS_LINEAR + 1):
    tr_loss, tr_acc = linear_epoch(encoder, train_cls_loader, train=True)
    va_loss, va_acc = linear_epoch(encoder, val_cls_loader,   train=False)

    # log history
    lin_hist["epoch"].append(ep)
    lin_hist["train_loss"].append(tr_loss)
    lin_hist["train_acc"].append(tr_acc * 100.0)  # store as %
    lin_hist["val_loss"].append(va_loss)
    lin_hist["val_acc"].append(va_acc * 100.0)    # store as %

    # save best head
    if va_acc > best_val_acc + 1e-6:
        best_val_acc = va_acc
        torch.save(
            {"state_dict": head.state_dict(), "feat_dim": FEAT_DIM, "num_classes": num_classes},
            BEST_HEAD_PATH
        )
        print(f"[Linear {ep}] Saved best head -> {BEST_HEAD_PATH}")

    print(f"[Linear {ep:02d}] "
          f"train: loss={tr_loss:.4f}, acc={tr_acc*100:.2f}% | "
          f"val: loss={va_loss:.4f}, acc={va_acc*100:.2f}%")
# Out:
# Encoder load (missing/unexpected): <All keys matched successfully>
# [Linear 1] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 01] train: loss=0.4028, acc=86.26% | val: loss=0.3510, acc=88.19%
# [Linear 02] train: loss=0.3056, acc=89.62% | val: loss=0.3856, acc=87.94%
# [Linear 3] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 03] train: loss=0.2709, acc=90.88% | val: loss=0.3220, acc=89.07%
# [Linear 04] train: loss=0.2601, acc=91.15% | val: loss=0.3522, acc=88.59%
# [Linear 5] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 05] train: loss=0.2497, acc=91.38% | val: loss=0.2815, acc=90.98%
# [Linear 6] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 06] train: loss=0.2403, acc=91.83% | val: loss=0.2514, acc=91.33%
# [Linear 7] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 07] train: loss=0.2361, acc=92.15% | val: loss=0.2443, acc=92.54%
# [Linear 08] train: loss=0.2231, acc=92.43% | val: loss=0.2454, acc=91.67%
# [Linear 09] train: loss=0.2168, acc=92.63% | val: loss=0.2337, acc=92.37%
# [Linear 10] train: loss=0.2164, acc=92.71% | val: loss=0.2379, acc=92.41%
# [Linear 11] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 11] train: loss=0.2118, acc=92.58% | val: loss=0.2275, acc=92.59%
# [Linear 12] train: loss=0.2068, acc=93.10% | val: loss=0.2580, acc=91.76%
# [Linear 13] train: loss=0.2072, acc=93.16% | val: loss=0.2555, acc=91.56%
# [Linear 14] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 14] train: loss=0.1971, acc=93.34% | val: loss=0.2096, acc=92.87%
# [Linear 15] train: loss=0.1869, acc=93.43% | val: loss=0.2664, acc=91.19%
# [Linear 16] train: loss=0.1905, acc=93.47% | val: loss=0.2181, acc=92.80%
# [Linear 17] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 17] train: loss=0.1857, acc=93.71% | val: loss=0.2089, acc=93.52%
# [Linear 18] train: loss=0.1930, acc=93.46% | val: loss=0.2342, acc=92.57%
# [Linear 19] train: loss=0.1848, acc=93.96% | val: loss=0.2561, acc=91.85%
# [Linear 20] train: loss=0.1873, acc=93.74% | val: loss=0.2402, acc=92.52%
# [Linear 21] train: loss=0.1789, acc=94.01% | val: loss=0.1997, acc=93.28%
# [Linear 22] train: loss=0.1859, acc=93.77% | val: loss=0.2462, acc=91.78%
# [Linear 23] train: loss=0.1814, acc=93.76% | val: loss=0.2021, acc=93.13%
# [Linear 24] train: loss=0.1690, acc=94.22% | val: loss=0.2575, acc=92.07%
# [Linear 25] train: loss=0.1725, acc=94.19% | val: loss=0.2123, acc=93.33%
# [Linear 26] train: loss=0.1763, acc=93.93% | val: loss=0.2696, acc=91.59%
# [Linear 27] train: loss=0.1661, acc=94.18% | val: loss=0.2644, acc=91.87%
# [Linear 28] train: loss=0.1827, acc=93.90% | val: loss=0.2312, acc=93.00%
# [Linear 29] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 29] train: loss=0.1644, acc=94.31% | val: loss=0.1895, acc=93.76%
# [Linear 30] train: loss=0.1743, acc=94.07% | val: loss=0.2102, acc=93.41%
# [Linear 31] train: loss=0.1738, acc=94.19% | val: loss=0.2022, acc=93.56%
# [Linear 32] train: loss=0.1608, acc=94.47% | val: loss=0.2826, acc=91.70%
# [Linear 33] train: loss=0.1657, acc=94.34% | val: loss=0.2690, acc=91.61%
# [Linear 34] train: loss=0.1561, acc=94.66% | val: loss=0.2491, acc=92.09%
# [Linear 35] train: loss=0.1510, acc=94.77% | val: loss=0.2015, acc=93.43%
# [Linear 36] train: loss=0.1507, acc=94.75% | val: loss=0.2218, acc=93.17%
# [Linear 37] train: loss=0.1503, acc=94.75% | val: loss=0.2033, acc=93.33%
# [Linear 38] train: loss=0.1575, acc=94.67% | val: loss=0.2081, acc=93.35%
# [Linear 39] train: loss=0.1500, acc=94.84% | val: loss=0.2043, acc=93.46%
# [Linear 40] train: loss=0.1454, acc=95.02% | val: loss=0.2759, acc=91.43%
# [Linear 41] train: loss=0.1476, acc=94.97% | val: loss=0.2182, acc=93.24%
# [Linear 42] train: loss=0.1468, acc=94.94% | val: loss=0.2045, acc=93.43%
# [Linear 43] train: loss=0.1427, acc=95.17% | val: loss=0.2202, acc=92.89%
# [Linear 44] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 44] train: loss=0.1457, acc=94.98% | val: loss=0.1928, acc=93.85%
# [Linear 45] train: loss=0.1374, acc=95.15% | val: loss=0.2277, acc=93.04%
# [Linear 46] train: loss=0.1520, acc=94.79% | val: loss=0.2493, acc=92.46%
# [Linear 47] train: loss=0.1384, acc=95.08% | val: loss=0.1907, acc=93.57%
# [Linear 48] train: loss=0.1413, acc=95.03% | val: loss=0.2182, acc=93.24%
# [Linear 49] train: loss=0.1401, acc=95.06% | val: loss=0.2183, acc=93.48%
# [Linear 50] train: loss=0.1418, acc=94.99% | val: loss=0.2157, acc=93.20%
# [Linear 51] train: loss=0.1318, acc=95.37% | val: loss=0.2421, acc=92.48%
# [Linear 52] train: loss=0.1336, acc=95.41% | val: loss=0.2042, acc=93.65%
# [Linear 53] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 53] train: loss=0.1284, acc=95.49% | val: loss=0.1926, acc=93.93%
# [Linear 54] train: loss=0.1268, acc=95.58% | val: loss=0.2584, acc=92.15%
# [Linear 55] train: loss=0.1384, acc=95.15% | val: loss=0.1901, acc=93.67%
# [Linear 56] train: loss=0.1325, acc=95.46% | val: loss=0.1985, acc=93.56%
# [Linear 57] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 57] train: loss=0.1236, acc=95.56% | val: loss=0.1923, acc=94.00%
# [Linear 58] train: loss=0.1341, acc=95.29% | val: loss=0.1991, acc=93.67%
# [Linear 59] train: loss=0.1224, acc=95.82% | val: loss=0.2200, acc=93.28%
# [Linear 60] train: loss=0.1295, acc=95.50% | val: loss=0.1970, acc=93.74%
# [Linear 61] train: loss=0.1230, acc=95.72% | val: loss=0.2509, acc=92.35%
# [Linear 62] train: loss=0.1250, acc=95.58% | val: loss=0.2453, acc=91.76%
# [Linear 63] train: loss=0.1290, acc=95.43% | val: loss=0.1987, acc=93.74%
# [Linear 64] train: loss=0.1211, acc=95.72% | val: loss=0.2301, acc=92.80%
# [Linear 65] train: loss=0.1208, acc=95.71% | val: loss=0.2055, acc=93.63%
# [Linear 66] train: loss=0.1209, acc=95.75% | val: loss=0.2114, acc=93.26%
# [Linear 67] train: loss=0.1177, acc=95.77% | val: loss=0.2202, acc=93.20%
# [Linear 68] train: loss=0.1184, acc=95.69% | val: loss=0.2276, acc=93.20%
# [Linear 69] train: loss=0.1152, acc=95.84% | val: loss=0.2251, acc=93.00%
# [Linear 70] train: loss=0.1196, acc=95.74% | val: loss=0.2330, acc=93.37%
# [Linear 71] train: loss=0.1154, acc=95.89% | val: loss=0.2618, acc=91.63%
# [Linear 72] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 72] train: loss=0.1211, acc=95.68% | val: loss=0.1905, acc=94.11%
# [Linear 73] train: loss=0.1222, acc=95.50% | val: loss=0.2062, acc=93.81%
# [Linear 74] train: loss=0.1129, acc=95.98% | val: loss=0.1986, acc=93.74%
# [Linear 75] train: loss=0.1168, acc=95.92% | val: loss=0.2053, acc=93.67%
# [Linear 76] train: loss=0.1127, acc=96.03% | val: loss=0.2207, acc=93.56%
# [Linear 77] train: loss=0.1190, acc=95.83% | val: loss=0.2342, acc=93.26%
# [Linear 78] train: loss=0.1135, acc=96.05% | val: loss=0.2106, acc=93.56%
# [Linear 79] train: loss=0.1071, acc=96.25% | val: loss=0.2233, acc=93.31%
# [Linear 80] train: loss=0.1103, acc=96.29% | val: loss=0.2176, acc=93.67%
# [Linear 81] train: loss=0.1164, acc=95.81% | val: loss=0.2299, acc=93.07%
# [Linear 82] train: loss=0.1155, acc=95.94% | val: loss=0.2499, acc=92.85%
# [Linear 83] train: loss=0.1195, acc=95.89% | val: loss=0.2069, acc=93.54%
# [Linear 84] train: loss=0.1049, acc=96.31% | val: loss=0.1918, acc=94.11%
# [Linear 85] train: loss=0.1121, acc=96.03% | val: loss=0.1984, acc=93.72%
# [Linear 86] train: loss=0.1073, acc=96.28% | val: loss=0.2309, acc=92.85%
# [Linear 87] train: loss=0.1107, acc=96.20% | val: loss=0.2388, acc=93.28%
# [Linear 88] train: loss=0.1134, acc=96.05% | val: loss=0.2584, acc=92.59%
# [Linear 89] train: loss=0.1110, acc=96.06% | val: loss=0.2153, acc=93.39%
# [Linear 90] train: loss=0.0997, acc=96.59% | val: loss=0.2223, acc=93.26%
# [Linear 91] train: loss=0.1049, acc=96.24% | val: loss=0.2262, acc=93.44%
# [Linear 92] train: loss=0.0968, acc=96.52% | val: loss=0.2027, acc=94.06%
# [Linear 93] train: loss=0.0990, acc=96.62% | val: loss=0.2104, acc=93.87%
# [Linear 94] train: loss=0.0981, acc=96.38% | val: loss=0.2323, acc=92.78%
# [Linear 95] train: loss=0.1021, acc=96.26% | val: loss=0.1983, acc=94.06%
# [Linear 96] Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 96] train: loss=0.1032, acc=96.30% | val: loss=0.1865, acc=94.30%
# [Linear 97] train: loss=0.0935, acc=96.58% | val: loss=0.2140, acc=93.80%
# [Linear 98] train: loss=0.0968, acc=96.51% | val: loss=0.2047, acc=93.70%
# [Linear 99] train: loss=0.1047, acc=96.32% | val: loss=0.2023, acc=94.06%
# [Linear 100] train: loss=0.1036, acc=96.19% | val: loss=0.2327, acc=93.54%
# [Linear 101] train: loss=0.1048, acc=96.28% | val: loss=0.2192, acc=93.70%
# [Linear 102] train: loss=0.0908, acc=96.72% | val: loss=0.2152, acc=93.80%
# [Linear 103] train: loss=0.0943, acc=96.76% | val: loss=0.2243, acc=93.50%
# [Linear 104] train: loss=0.0930, acc=96.62% | val: loss=0.2008, acc=94.07%
# [Linear 105] train: loss=0.0921, acc=96.79% | val: loss=0.2234, acc=93.17%
# [Linear 106] train: loss=0.0938, acc=96.68% | val: loss=0.2193, acc=93.69%
# [Linear 107] train: loss=0.0870, acc=96.99% | val: loss=0.2745, acc=92.81%
# [Linear 108] train: loss=0.1003, acc=96.44% | val: loss=0.2020, acc=93.91%
# [Linear 109] train: loss=0.0919, acc=96.68% | val: loss=0.2427, acc=92.65%
# [Linear 110] train: loss=0.0927, acc=96.67% | val: loss=0.2070, acc=93.94%
# [Linear 111] train: loss=0.0859, acc=96.99% | val: loss=0.1958, acc=94.11%
# [Linear 112] train: loss=0.0894, acc=96.86% | val: loss=0.2068, acc=93.85%
# [Linear 113] train: loss=0.0946, acc=96.66% | val: loss=0.2155, acc=93.67%
# [Linear 114] train: loss=0.0869, acc=96.88% | val: loss=0.2256, acc=93.39%
# [Linear 115] train: loss=0.0842, acc=97.03% | val: loss=0.2016, acc=94.06%
# [Linear 116] train: loss=0.0859, acc=96.97% | val: loss=0.2316, acc=93.41%
# [Linear 117] train: loss=0.0881, acc=96.80% | val: loss=0.1959, acc=93.98%
# [Linear 118] train: loss=0.0864, acc=96.80% | val: loss=0.2086, acc=93.63%
# [Linear 119] train: loss=0.0895, acc=96.76% | val: loss=0.2079, acc=93.96%
# [Linear 120] train: loss=0.0959, acc=96.61% | val: loss=0.2461, acc=92.69%
# [Linear 121] train: loss=0.0861, acc=96.92% | val: loss=0.2048, acc=93.70%
# [Linear 122] train: loss=0.0830, acc=97.08% | val: loss=0.2344, acc=93.07%
# [Linear 123] train: loss=0.0823, acc=97.08% | val: loss=0.2197, acc=93.52%
# [Linear 124] train: loss=0.0833, acc=97.00% | val: loss=0.2720, acc=92.24%
# [Linear 125] train: loss=0.0904, acc=96.87% | val: loss=0.2019, acc=93.85%
# [Linear 126] train: loss=0.0849, acc=96.96% | val: loss=0.2060, acc=93.56%
# [Linear 127] train: loss=0.0813, acc=97.16% | val: loss=0.2196, acc=93.72%
# [Linear 128] train: loss=0.0869, acc=96.80% | val: loss=0.2400, acc=93.43%
# [Linear 129] train: loss=0.0924, acc=96.64% | val: loss=0.2021, acc=94.09%
# [Linear 130] train: loss=0.0849, acc=96.96% | val: loss=0.2191, acc=93.46%
# [Linear 131] train: loss=0.0942, acc=96.61% | val: loss=0.2204, acc=93.33%
# [Linear 132] train: loss=0.0764, acc=97.21% | val: loss=0.2304, acc=93.46%
# [Linear 133] train: loss=0.0819, acc=97.00% | val: loss=0.2167, acc=93.09%
# [Linear 134] train: loss=0.0799, acc=97.12% | val: loss=0.2076, acc=93.87%
# [Linear 135] train: loss=0.0816, acc=97.05% | val: loss=0.2134, acc=93.65%
# [Linear 136] train: loss=0.0847, acc=96.99% | val: loss=0.2430, acc=93.43%
# [Linear 137] train: loss=0.0823, acc=97.06% | val: loss=0.2088, acc=93.91%
# [Linear 138] train: loss=0.0720, acc=97.51% | val: loss=0.2018, acc=94.07%
# [Linear 139] train: loss=0.0760, acc=97.37% | val: loss=0.2037, acc=94.19%
# [Linear 140] train: loss=0.0815, acc=97.05% | val: loss=0.2253, acc=93.50%
# [Linear 141] train: loss=0.0873, acc=96.98% | val: loss=0.1973, acc=93.94%
# [Linear 142] train: loss=0.0804, acc=97.23% | val: loss=0.2137, acc=93.78%
# [Linear 143] train: loss=0.0849, acc=96.96% | val: loss=0.2153, acc=93.93%
# [Linear 144] train: loss=0.0768, acc=97.26% | val: loss=0.2302, acc=93.48%
# [Linear 145] train: loss=0.0833, acc=97.08% | val: loss=0.2663, acc=93.28%
# [Linear 146] train: loss=0.0817, acc=97.10% | val: loss=0.2577, acc=92.70%
# [Linear 147] train: loss=0.0792, acc=97.02% | val: loss=0.2043, acc=93.56%
# [Linear 148] train: loss=0.0789, acc=97.19% | val: loss=0.2231, acc=93.69%
# [Linear 149] train: loss=0.0703, acc=97.51% | val: loss=0.2187, acc=93.39%
# [Linear 150] train: loss=0.0788, acc=97.15% | val: loss=0.2532, acc=92.70%
# [Linear 151] train: loss=0.0744, acc=97.34% | val: loss=0.2393, acc=93.17%
# [Linear 152] train: loss=0.0760, acc=97.28% | val: loss=0.2163, acc=93.78%
# [Linear 153] train: loss=0.0684, acc=97.71% | val: loss=0.2079, acc=93.69%
# [Linear 154] train: loss=0.0737, acc=97.33% | val: loss=0.2011, acc=94.15%
# [Linear 155] train: loss=0.0730, acc=97.54% | val: loss=0.2734, acc=92.13%
# [Linear 156] train: loss=0.0731, acc=97.35% | val: loss=0.2644, acc=92.98%
# [Linear 157] train: loss=0.0757, acc=97.37% | val: loss=0.2367, acc=93.44%
# [Linear 158] train: loss=0.0687, acc=97.55% | val: loss=0.2442, acc=93.07%
# [Linear 159] train: loss=0.0749, acc=97.42% | val: loss=0.2066, acc=93.76%
# [Linear 160] train: loss=0.0676, acc=97.54% | val: loss=0.2202, acc=93.37%
# [Linear 161] train: loss=0.0713, acc=97.43% | val: loss=0.2354, acc=93.33%
# [Linear 162] train: loss=0.0690, acc=97.48% | val: loss=0.2063, acc=93.76%
# [Linear 163] train: loss=0.0650, acc=97.72% | val: loss=0.2072, acc=94.06%
# [Linear 164] train: loss=0.0671, acc=97.72% | val: loss=0.2358, acc=93.43%
# [Linear 165] train: loss=0.0741, acc=97.25% | val: loss=0.2064, acc=94.20%
# [Linear 166] train: loss=0.0786, acc=97.22% | val: loss=0.2087, acc=94.11%
# [Linear 167] train: loss=0.0646, acc=97.69% | val: loss=0.2022, acc=94.15%
# [Linear 168] train: loss=0.0636, acc=97.91% | val: loss=0.2299, acc=93.30%
# [Linear 169] train: loss=0.0607, acc=97.80% | val: loss=0.2401, acc=92.85%
# [Linear 170] train: loss=0.0744, acc=97.30% | val: loss=0.2225, acc=93.72%
# [Linear 171] train: loss=0.0646, acc=97.70% | val: loss=0.2224, acc=93.78%
# [Linear 172] train: loss=0.0683, acc=97.59% | val: loss=0.2579, acc=92.67%
# [Linear 173] train: loss=0.0638, acc=97.76% | val: loss=0.2218, acc=93.72%
# [Linear 174] train: loss=0.0614, acc=97.88% | val: loss=0.2192, acc=93.70%
# [Linear 175] train: loss=0.0672, acc=97.60% | val: loss=0.2773, acc=92.65%
# [Linear 176] train: loss=0.0696, acc=97.59% | val: loss=0.3003, acc=92.17%
# [Linear 177] train: loss=0.0640, acc=97.76% | val: loss=0.2291, acc=93.33%
# [Linear 178] train: loss=0.0663, acc=97.72% | val: loss=0.2350, acc=93.09%
# [Linear 179] train: loss=0.0706, acc=97.49% | val: loss=0.2184, acc=93.89%
# [Linear 180] train: loss=0.0668, acc=97.54% | val: loss=0.2205, acc=93.98%
# [Linear 181] train: loss=0.0603, acc=97.88% | val: loss=0.2198, acc=93.83%
# [Linear 182] train: loss=0.0561, acc=98.09% | val: loss=0.2174, acc=94.06%
# [Linear 183] train: loss=0.0604, acc=97.81% | val: loss=0.2323, acc=93.20%
# [Linear 184] train: loss=0.0595, acc=97.90% | val: loss=0.2395, acc=93.57%
# [Linear 185] train: loss=0.0726, acc=97.50% | val: loss=0.2437, acc=93.54%
# [Linear 186] train: loss=0.0655, acc=97.83% | val: loss=0.2167, acc=93.56%
# [Linear 187] train: loss=0.0613, acc=97.89% | val: loss=0.2100, acc=94.13%
# [Linear 188] train: loss=0.0591, acc=97.84% | val: loss=0.2318, acc=93.80%
# [Linear 189] train: loss=0.0592, acc=97.92% | val: loss=0.2198, acc=93.87%
# [Linear 190] train: loss=0.0658, acc=97.63% | val: loss=0.2467, acc=93.15%
# [Linear 191] train: loss=0.0647, acc=97.57% | val: loss=0.2242, acc=93.67%
# [Linear 192] train: loss=0.0651, acc=97.65% | val: loss=0.2140, acc=94.06%
# [Linear 193] train: loss=0.0596, acc=97.87% | val: loss=0.2273, acc=93.69%
# [Linear 194] train: loss=0.0604, acc=97.87% | val: loss=0.2518, acc=92.89%
# [Linear 195] train: loss=0.0580, acc=97.97% | val: loss=0.2244, acc=93.74%
# [Linear 196] train: loss=0.0610, acc=97.87% | val: loss=0.2456, acc=93.41%
# [Linear 197] train: loss=0.0548, acc=98.22% | val: loss=0.2131, acc=93.83%
# [Linear 198] train: loss=0.0637, acc=97.76% | val: loss=0.2112, acc=94.09%
# [Linear 199] train: loss=0.0619, acc=97.79% | val: loss=0.2543, acc=93.19%
# [Linear 200] train: loss=0.0558, acc=98.05% | val: loss=0.2106, acc=94.04%
# [Linear 201] train: loss=0.0580, acc=97.80% | val: loss=0.2481, acc=93.09%
# [Linear 202] train: loss=0.0583, acc=97.98% | val: loss=0.2236, acc=93.43%
# [Linear 203] train: loss=0.0527, acc=98.14% | val: loss=0.2253, acc=93.76%
# [Linear 204] train: loss=0.0569, acc=97.93% | val: loss=0.2541, acc=93.43%
# [Linear 205] train: loss=0.0547, acc=98.12% | val: loss=0.2261, acc=93.65%
# [Linear 206] train: loss=0.0567, acc=97.97% | val: loss=0.2303, acc=93.67%
# [Linear 207] train: loss=0.0631, acc=97.83% | val: loss=0.2312, acc=93.76%
# [Linear 208] train: loss=0.0547, acc=98.07% | val: loss=0.2235, acc=93.91%
# [Linear 209] train: loss=0.0585, acc=97.87% | val: loss=0.2252, acc=93.57%
# [Linear 210] train: loss=0.0526, acc=98.14% | val: loss=0.2136, acc=94.17%
# [Linear 211] train: loss=0.0552, acc=98.16% | val: loss=0.2302, acc=93.35%
# [Linear 212] train: loss=0.0554, acc=98.08% | val: loss=0.2073, acc=94.19%
# [Linear 213] train: loss=0.0545, acc=97.98% | val: loss=0.2239, acc=93.72%
# [Linear 214] train: loss=0.0583, acc=97.94% | val: loss=0.2316, acc=93.54%
# [Linear 215] train: loss=0.0579, acc=97.85% | val: loss=0.2666, acc=92.96%
# [Linear 216] train: loss=0.0582, acc=97.93% | val: loss=0.2343, acc=93.17%
# [Linear 217] train: loss=0.0527, acc=98.12% | val: loss=0.2222, acc=93.65%
# [Linear 218] train: loss=0.0478, acc=98.39% | val: loss=0.2091, acc=93.94%
# [Linear 219] train: loss=0.0536, acc=98.13% | val: loss=0.2605, acc=92.69%
# [Linear 220] train: loss=0.0644, acc=97.71% | val: loss=0.2654, acc=93.59%
# [Linear 221] train: loss=0.0647, acc=97.58% | val: loss=0.2324, acc=93.67%
# [Linear 222] train: loss=0.0523, acc=98.08% | val: loss=0.2394, acc=93.52%
# [Linear 223] train: loss=0.0493, acc=98.33% | val: loss=0.2353, acc=93.43%
# [Linear 224] train: loss=0.0494, acc=98.35% | val: loss=0.2433, acc=93.31%
# [Linear 225] train: loss=0.0610, acc=97.86% | val: loss=0.3245, acc=92.41%
# [Linear 226] train: loss=0.0607, acc=97.80% | val: loss=0.2461, acc=93.57%
# [Linear 227] train: loss=0.0585, acc=97.92% | val: loss=0.3286, acc=91.91%
# [Linear 228] train: loss=0.0517, acc=98.24% | val: loss=0.2261, acc=93.59%
# [Linear 229] train: loss=0.0524, acc=98.07% | val: loss=0.2375, acc=93.94%
# [Linear 230] train: loss=0.0524, acc=98.15% | val: loss=0.2335, acc=93.67%
# [Linear 231] train: loss=0.0578, acc=98.01% | val: loss=0.2180, acc=93.78%
# [Linear 232] train: loss=0.0450, acc=98.55% | val: loss=0.2314, acc=93.67%
# [Linear 233] train: loss=0.0437, acc=98.59% | val: loss=0.2302, acc=93.80%
# [Linear 234] train: loss=0.0468, acc=98.39% | val: loss=0.2468, acc=93.41%
# [Linear 235] train: loss=0.0581, acc=98.05% | val: loss=0.2364, acc=93.91%
# [Linear 236] train: loss=0.0474, acc=98.39% | val: loss=0.2140, acc=94.04%
# [Linear 237] train: loss=0.0532, acc=98.25% | val: loss=0.2557, acc=93.13%
# [Linear 238] train: loss=0.0480, acc=98.37% | val: loss=0.2347, acc=93.63%
# [Linear 239] train: loss=0.0466, acc=98.51% | val: loss=0.2250, acc=93.72%
# [Linear 240] train: loss=0.0490, acc=98.33% | val: loss=0.2485, acc=93.83%
# [Linear 241] train: loss=0.0479, acc=98.32% | val: loss=0.2714, acc=93.07%
# [Linear 242] train: loss=0.0591, acc=97.81% | val: loss=0.2380, acc=93.70%
# [Linear 243] train: loss=0.0441, acc=98.53% | val: loss=0.2225, acc=93.85%
# [Linear 244] train: loss=0.0459, acc=98.45% | val: loss=0.2534, acc=93.30%
# [Linear 245] train: loss=0.0421, acc=98.56% | val: loss=0.2447, acc=93.28%
# [Linear 246] train: loss=0.0528, acc=98.07% | val: loss=0.2356, acc=93.46%
# [Linear 247] train: loss=0.0484, acc=98.35% | val: loss=0.2319, acc=93.81%
# [Linear 248] train: loss=0.0450, acc=98.43% | val: loss=0.2220, acc=94.00%
# [Linear 249] train: loss=0.0479, acc=98.37% | val: loss=0.2604, acc=93.54%
# [Linear 250] train: loss=0.0588, acc=97.89% | val: loss=0.2348, acc=93.91%
# [Linear 251] train: loss=0.0447, acc=98.49% | val: loss=0.2688, acc=92.93%
# [Linear 252] train: loss=0.0448, acc=98.38% | val: loss=0.2478, acc=93.69%
# [Linear 253] train: loss=0.0457, acc=98.39% | val: loss=0.2946, acc=92.39%
# [Linear 254] train: loss=0.0487, acc=98.24% | val: loss=0.2931, acc=92.78%
# [Linear 255] train: loss=0.0527, acc=98.06% | val: loss=0.2181, acc=94.06%
# [Linear 256] train: loss=0.0461, acc=98.45% | val: loss=0.2444, acc=93.63%
# [Linear 257] train: loss=0.0394, acc=98.76% | val: loss=0.2353, acc=93.31%
# [Linear 258] train: loss=0.0466, acc=98.37% | val: loss=0.2543, acc=93.37%
# [Linear 259] train: loss=0.0441, acc=98.39% | val: loss=0.2707, acc=92.83%
# [Linear 260] train: loss=0.0451, acc=98.51% | val: loss=0.2313, acc=93.30%
# [Linear 261] train: loss=0.0399, acc=98.70% | val: loss=0.2245, acc=94.02%
# [Linear 262] train: loss=0.0391, acc=98.71% | val: loss=0.2868, acc=92.85%
# [Linear 263] train: loss=0.0528, acc=98.18% | val: loss=0.2420, acc=93.43%
# [Linear 264] train: loss=0.0504, acc=98.17% | val: loss=0.2629, acc=93.65%
# [Linear 265] train: loss=0.0448, acc=98.49% | val: loss=0.2348, acc=93.76%
# [Linear 266] train: loss=0.0454, acc=98.39% | val: loss=0.2222, acc=94.04%
# [Linear 267] train: loss=0.0376, acc=98.82% | val: loss=0.2293, acc=93.78%
# [Linear 268] train: loss=0.0385, acc=98.77% | val: loss=0.2554, acc=93.56%
# [Linear 269] train: loss=0.0419, acc=98.62% | val: loss=0.2345, acc=93.85%
# [Linear 270] train: loss=0.0456, acc=98.39% | val: loss=0.2330, acc=93.98%
# [Linear 271] train: loss=0.0451, acc=98.49% | val: loss=0.2692, acc=93.28%
# [Linear 272] train: loss=0.0419, acc=98.57% | val: loss=0.2700, acc=93.22%
# [Linear 273] train: loss=0.0589, acc=97.89% | val: loss=0.2380, acc=93.98%
# [Linear 274] train: loss=0.0387, acc=98.68% | val: loss=0.2845, acc=93.37%
# [Linear 275] train: loss=0.0415, acc=98.57% | val: loss=0.2433, acc=94.06%
# [Linear 276] train: loss=0.0465, acc=98.42% | val: loss=0.2374, acc=93.72%
# [Linear 277] train: loss=0.0339, acc=99.02% | val: loss=0.2269, acc=93.85%
# [Linear 278] train: loss=0.0424, acc=98.59% | val: loss=0.2340, acc=93.69%
# [Linear 279] train: loss=0.0391, acc=98.62% | val: loss=0.2823, acc=93.00%
# [Linear 280] train: loss=0.0503, acc=98.31% | val: loss=0.2709, acc=93.11%
# [Linear 281] train: loss=0.0447, acc=98.51% | val: loss=0.2298, acc=93.56%
# [Linear 282] train: loss=0.0359, acc=98.89% | val: loss=0.2365, acc=93.69%
# [Linear 283] train: loss=0.0476, acc=98.50% | val: loss=0.2968, acc=93.04%
# [Linear 284] train: loss=0.0483, acc=98.43% | val: loss=0.2298, acc=93.96%
# [Linear 285] train: loss=0.0336, acc=98.97% | val: loss=0.2556, acc=93.11%
# [Linear 286] train: loss=0.0410, acc=98.59% | val: loss=0.2796, acc=93.24%
# [Linear 287] train: loss=0.0550, acc=98.06% | val: loss=0.2540, acc=93.41%
# [Linear 288] train: loss=0.0333, acc=98.92% | val: loss=0.2964, acc=92.28%
# [Linear 289] train: loss=0.0341, acc=98.92% | val: loss=0.2486, acc=93.41%
# [Linear 290] train: loss=0.0364, acc=98.92% | val: loss=0.2644, acc=93.37%
# [Linear 291] train: loss=0.0399, acc=98.77% | val: loss=0.2399, acc=93.50%
# [Linear 292] train: loss=0.0341, acc=98.98% | val: loss=0.2702, acc=93.17%
# [Linear 293] train: loss=0.0505, acc=98.23% | val: loss=0.2364, acc=93.50%
# [Linear 294] train: loss=0.0392, acc=98.72% | val: loss=0.2379, acc=94.09%
# [Linear 295] train: loss=0.0343, acc=98.97% | val: loss=0.2392, acc=93.67%
# [Linear 296] train: loss=0.0393, acc=98.70% | val: loss=0.2950, acc=93.30%
# [Linear 297] train: loss=0.0405, acc=98.68% | val: loss=0.2408, acc=93.98%
# [Linear 298] train: loss=0.0339, acc=98.88% | val: loss=0.2360, acc=93.78%
# [Linear 299] train: loss=0.0370, acc=98.89% | val: loss=0.2716, acc=93.19%
# [Linear 300] train: loss=0.0336, acc=98.96% | val: loss=0.2709, acc=93.44%
# [Linear 301] train: loss=0.0415, acc=98.61% | val: loss=0.2686, acc=93.30%
# [Linear 302] train: loss=0.0303, acc=99.10% | val: loss=0.2467, acc=93.33%
# [Linear 303] train: loss=0.0366, acc=98.74% | val: loss=0.2513, acc=93.69%
# [Linear 304] train: loss=0.0391, acc=98.71% | val: loss=0.2844, acc=93.30%
# [Linear 305] train: loss=0.0415, acc=98.59% | val: loss=0.2496, acc=93.54%
# [Linear 306] train: loss=0.0498, acc=98.25% | val: loss=0.3336, acc=91.80%
# [Linear 307] train: loss=0.0396, acc=98.73% | val: loss=0.2304, acc=94.06%
# [Linear 308] train: loss=0.0294, acc=99.16% | val: loss=0.2303, acc=93.85%
# [Linear 309] train: loss=0.0343, acc=98.83% | val: loss=0.2511, acc=93.87%
# [Linear 310] train: loss=0.0350, acc=98.92% | val: loss=0.2367, acc=93.63%
# [Linear 311] train: loss=0.0365, acc=98.85% | val: loss=0.2689, acc=93.06%
# [Linear 312] train: loss=0.0288, acc=99.26% | val: loss=0.2303, acc=93.65%
# [Linear 313] train: loss=0.0313, acc=98.97% | val: loss=0.2412, acc=93.65%
# [Linear 314] train: loss=0.0361, acc=98.82% | val: loss=0.2832, acc=92.74%
# [Linear 315] train: loss=0.0445, acc=98.45% | val: loss=0.2350, acc=94.04%
# [Linear 316] train: loss=0.0402, acc=98.71% | val: loss=0.2299, acc=93.76%
# [Linear 317] train: loss=0.0294, acc=99.20% | val: loss=0.2469, acc=93.91%
# [Linear 318] train: loss=0.0428, acc=98.52% | val: loss=0.2490, acc=93.89%
# [Linear 319] train: loss=0.0308, acc=99.06% | val: loss=0.2516, acc=93.74%
# [Linear 320] train: loss=0.0369, acc=98.76% | val: loss=0.2587, acc=93.83%
# [Linear 321] train: loss=0.0321, acc=99.02% | val: loss=0.2842, acc=93.02%
# [Linear 322] train: loss=0.0313, acc=99.06% | val: loss=0.2563, acc=93.87%
# [Linear 323] train: loss=0.0345, acc=98.86% | val: loss=0.3509, acc=91.72%
# [Linear 324] train: loss=0.0382, acc=98.67% | val: loss=0.2610, acc=93.78%
# [Linear 325] train: loss=0.0465, acc=98.31% | val: loss=0.2929, acc=92.94%
# [Linear 326] train: loss=0.0337, acc=99.00% | val: loss=0.2377, acc=93.78%
# [Linear 327] train: loss=0.0293, acc=99.17% | val: loss=0.2826, acc=93.43%
# [Linear 328] train: loss=0.0378, acc=98.74% | val: loss=0.2405, acc=94.02%
# [Linear 329] train: loss=0.0348, acc=98.88% | val: loss=0.2487, acc=93.94%
# [Linear 330] train: loss=0.0359, acc=98.76% | val: loss=0.2412, acc=94.19%
# [Linear 331] train: loss=0.0307, acc=98.99% | val: loss=0.2698, acc=93.02%
# [Linear 332] train: loss=0.0404, acc=98.71% | val: loss=0.2562, acc=93.72%
# [Linear 333] train: loss=0.0310, acc=99.05% | val: loss=0.2398, acc=93.74%
# [Linear 334] train: loss=0.0301, acc=99.08% | val: loss=0.2932, acc=92.57%
# [Linear 335] train: loss=0.0477, acc=98.50% | val: loss=0.3766, acc=92.02%
# [Linear 336] train: loss=0.0274, acc=99.21% | val: loss=0.2645, acc=93.54%
# [Linear 337] train: loss=0.0263, acc=99.27% | val: loss=0.2509, acc=93.48%
# [Linear 338] train: loss=0.0374, acc=98.77% | val: loss=0.2684, acc=93.41%
# [Linear 339] train: loss=0.0263, acc=99.23% | val: loss=0.2407, acc=93.98%
# [Linear 340] train: loss=0.0331, acc=98.96% | val: loss=0.2497, acc=93.63%
# [Linear 341] train: loss=0.0303, acc=99.07% | val: loss=0.2464, acc=93.57%
# [Linear 342] train: loss=0.0291, acc=99.19% | val: loss=0.2445, acc=94.00%
# [Linear 343] train: loss=0.0319, acc=98.99% | val: loss=0.2431, acc=93.78%
# [Linear 344] train: loss=0.0337, acc=98.99% | val: loss=0.2878, acc=92.78%
# [Linear 345] train: loss=0.0315, acc=98.95% | val: loss=0.2436, acc=93.63%
# [Linear 346] train: loss=0.0345, acc=98.90% | val: loss=0.3147, acc=92.72%
# [Linear 347] train: loss=0.0385, acc=98.75% | val: loss=0.2400, acc=93.93%
# [Linear 348] train: loss=0.0322, acc=98.94% | val: loss=0.3110, acc=92.37%
# [Linear 349] train: loss=0.0266, acc=99.18% | val: loss=0.2876, acc=93.22%
# [Linear 350] train: loss=0.0322, acc=99.02% | val: loss=0.2449, acc=93.89%
# [Linear 351] train: loss=0.0250, acc=99.30% | val: loss=0.2586, acc=93.70%
# [Linear 352] train: loss=0.0300, acc=99.12% | val: loss=0.2902, acc=93.13%
# [Linear 353] train: loss=0.0374, acc=98.70% | val: loss=0.2627, acc=93.70%
# [Linear 354] train: loss=0.0324, acc=98.86% | val: loss=0.2413, acc=93.72%
# [Linear 355] train: loss=0.0323, acc=98.98% | val: loss=0.2620, acc=93.80%
# [Linear 356] train: loss=0.0274, acc=99.17% | val: loss=0.2507, acc=93.59%
# [Linear 357] train: loss=0.0266, acc=99.19% | val: loss=0.2668, acc=93.17%
# [Linear 358] train: loss=0.0246, acc=99.27% | val: loss=0.2633, acc=93.83%
# [Linear 359] train: loss=0.0241, acc=99.43% | val: loss=0.2528, acc=93.81%
# [Linear 360] train: loss=0.0342, acc=98.97% | val: loss=0.2689, acc=93.70%
# [Linear 361] train: loss=0.0242, acc=99.31% | val: loss=0.2524, acc=93.61%
# [Linear 362] train: loss=0.0322, acc=98.93% | val: loss=0.2865, acc=93.37%
# [Linear 363] train: loss=0.0274, acc=99.22% | val: loss=0.2819, acc=92.94%
# [Linear 364] train: loss=0.0382, acc=98.69% | val: loss=0.2825, acc=93.44%
# [Linear 365] train: loss=0.0234, acc=99.39% | val: loss=0.2615, acc=93.87%
# [Linear 366] train: loss=0.0267, acc=99.21% | val: loss=0.2611, acc=93.91%
# [Linear 367] train: loss=0.0302, acc=99.03% | val: loss=0.2508, acc=93.48%
# [Linear 368] train: loss=0.0371, acc=98.69% | val: loss=0.2720, acc=93.54%
# [Linear 369] train: loss=0.0305, acc=99.00% | val: loss=0.2520, acc=93.59%
# [Linear 370] train: loss=0.0347, acc=98.82% | val: loss=0.2585, acc=93.94%
# [Linear 371] train: loss=0.0250, acc=99.22% | val: loss=0.2558, acc=93.39%
# [Linear 372] train: loss=0.0236, acc=99.40% | val: loss=0.2497, acc=93.83%
# [Linear 373] train: loss=0.0251, acc=99.29% | val: loss=0.2477, acc=93.98%
# [Linear 374] train: loss=0.0397, acc=98.60% | val: loss=0.2707, acc=93.44%
# [Linear 375] train: loss=0.0245, acc=99.29% | val: loss=0.2625, acc=93.48%
# [Linear 376] train: loss=0.0222, acc=99.43% | val: loss=0.3178, acc=92.09%
# [Linear 377] train: loss=0.0247, acc=99.35% | val: loss=0.2563, acc=93.74%
# [Linear 378] train: loss=0.0290, acc=99.13% | val: loss=0.3106, acc=93.02%
# [Linear 379] train: loss=0.0371, acc=98.79% | val: loss=0.2993, acc=92.78%
# [Linear 380] train: loss=0.0321, acc=98.98% | val: loss=0.2463, acc=93.67%
# [Linear 381] train: loss=0.0290, acc=99.11% | val: loss=0.2482, acc=93.93%
# [Linear 382] train: loss=0.0262, acc=99.28% | val: loss=0.2504, acc=93.87%
# [Linear 383] train: loss=0.0433, acc=98.57% | val: loss=0.2592, acc=93.70%
# [Linear 384] train: loss=0.0305, acc=98.97% | val: loss=0.2622, acc=93.46%
# [Linear 385] train: loss=0.0200, acc=99.51% | val: loss=0.2608, acc=93.69%
# [Linear 386] train: loss=0.0246, acc=99.28% | val: loss=0.2533, acc=93.70%
# [Linear 387] train: loss=0.0231, acc=99.30% | val: loss=0.2645, acc=93.89%
# [Linear 388] train: loss=0.0222, acc=99.43% | val: loss=0.2575, acc=93.98%
# [Linear 389] train: loss=0.0334, acc=98.93% | val: loss=0.3396, acc=92.69%
# [Linear 390] train: loss=0.0349, acc=98.84% | val: loss=0.2529, acc=93.85%
# [Linear 391] train: loss=0.0207, acc=99.44% | val: loss=0.2587, acc=93.52%
# [Linear 392] train: loss=0.0227, acc=99.34% | val: loss=0.2628, acc=93.57%
# [Linear 393] train: loss=0.0270, acc=99.11% | val: loss=0.2857, acc=93.11%
# [Linear 394] train: loss=0.0275, acc=99.17% | val: loss=0.2984, acc=93.04%
# [Linear 395] train: loss=0.0380, acc=98.79% | val: loss=0.2660, acc=93.69%
# [Linear 396] train: loss=0.0351, acc=99.05% | val: loss=0.3017, acc=93.44%
# [Linear 397] train: loss=0.0309, acc=99.02% | val: loss=0.2775, acc=93.80%
# [Linear 398] train: loss=0.0241, acc=99.34% | val: loss=0.2691, acc=93.70%
# [Linear 399] train: loss=0.0191, acc=99.59% | val: loss=0.2477, acc=93.81%
# [Linear 400] train: loss=0.0189, acc=99.55% | val: loss=0.2574, acc=93.52%

# %%
# --- Accuracy curve (%)
plt.figure(figsize=(7,4))
plt.plot(lin_hist["epoch"], lin_hist["train_acc"], label="Train Acc (%)")
plt.plot(lin_hist["epoch"], lin_hist["val_acc"],   label="Val Acc (%)")
plt.xlabel("Epoch"); plt.ylabel("Accuracy (%)")
plt.title("Linear Evaluation — Accuracy")
plt.legend(); 
plt.tight_layout()
plt.show()

# --- Loss curve
plt.figure(figsize=(7,4))
plt.plot(lin_hist["epoch"], lin_hist["train_loss"], label="Train Loss")
plt.plot(lin_hist["epoch"], lin_hist["val_loss"],   label="Val Loss")
plt.xlabel("Epoch"); plt.ylabel("Loss")
plt.title("Linear Evaluation — Loss")
plt.legend(); 
plt.tight_layout()
plt.show()

# %%
# ---- evaluate on TEST ----
all_y, all_pred = [], []
crit = nn.CrossEntropyLoss()
test_loss, total = 0.0, 0

with torch.no_grad():
    for x, y in test_cls_loader:
        x = x.to(DEVICE, non_blocking=True)
        y = y.to(DEVICE, non_blocking=True)

        feats = encoder(x)
        logits = head(feats)  # Use `head` instead of `lin_model`
        loss = crit(logits, y)

        pred = torch.argmax(logits, dim=1).cpu().numpy().tolist()
        all_pred.extend(pred)
        all_y.extend(y.cpu().numpy().tolist())

        test_loss += loss.item() * x.size(0)
        total += y.size(0)

acc = accuracy_score(all_y, all_pred)
test_loss = test_loss / max(1, total)

print(f"Test Accuracy: {acc*100:.2f}%")
print(classification_report(all_y, all_pred, digits=4, zero_division=0))  #  warning fixed
# Out:
# Test Accuracy: 94.93%
#               precision    recall  f1-score   support
#
#            0     0.9585    0.9233    0.9406       300
#            1     0.9868    0.9933    0.9900       300
#            2     0.9259    0.9167    0.9213       300
#            3     0.9132    0.8840    0.8984       250
#            4     0.9759    0.9720    0.9739       250
#            5     0.9495    0.9400    0.9447       200
#            6     0.9044    0.9080    0.9062       250
#            7     0.9967    0.9967    0.9967       300
#            8     0.8645    0.9440    0.9025       250
#            9     1.0000    0.9967    0.9983       300
#
#     accuracy                         0.9493      2700
#    macro avg     0.9475    0.9475    0.9473      2700
# weighted avg     0.9499    0.9493    0.9494      2700

# %%
@torch.no_grad()
def extract_features(encoder, loader, device=None):
    """Freeze encoder → collect features & labels from a loader."""
    if device is None:
        device = next(encoder.parameters()).device
    encoder.eval()
    feats, labels = [], []
    for x, y in loader:
        x = x.to(device, non_blocking=True)
        z = encoder(x)              # shape: [B, D]
        z = z.detach().cpu().numpy()
        y = y.detach().cpu().numpy()
        feats.append(z); labels.append(y)
    feats  = np.concatenate(feats, axis=0)
    labels = np.concatenate(labels, axis=0)
    return feats, labels

def silhouette_cosine(feats, labels):
    """Silhouette score with cosine distance; safe when a single class present."""
    if len(np.unique(labels)) < 2 or len(labels) < 3:
        return float("nan")
    # sklearn expects a similarity converted to distance for 'cosine'
    return silhouette_score(feats, labels, metric="cosine")

def tsne_plot_3d(feats, labels, title,
                 perplexity=30, max_points=5000, seed=42, save_html=None):
    """3D t-SNE (Plotly) — caps points, auto-safe perplexity, saves HTML if path given."""
    # cap points for speed
    if feats.shape[0] > max_points:
        idx = np.random.RandomState(seed).choice(feats.shape[0], size=max_points, replace=False)
        feats = feats[idx]; labels = labels[idx]

    # t-SNE rule: perplexity < n_samples
    n = feats.shape[0]
    perp = min(perplexity, max(5, n // 3))  # keep within a safe range

    emb = TSNE(
        n_components=3, perplexity=perp, init="pca",
        learning_rate="auto", random_state=seed, n_iter=1000, verbose=0
    ).fit_transform(feats)

    fig = px.scatter_3d(
        x=emb[:,0], y=emb[:,1], z=emb[:,2],
        color=labels.astype(str), title=title, height=700, width=900
    )
    fig.update_traces(marker=dict(size=3))
    if save_html:
        fig.write_html(save_html)
        print(f"Saved interactive HTML to: {save_html}")
    fig.show()

# %%
# TRAIN set clusters (frozen encoder)
train_feats, train_labels = extract_features(encoder, train_cls_loader, device=DEVICE)
print(f"Training silhouette score (cosine): {silhouette_cosine(train_feats, train_labels):.4f}")

tsne_plot_3d(
    train_feats, train_labels,
    title="3D t-SNE (train features)",
    perplexity=30, max_points=5000, seed=42,
    save_html="/kaggle/working/tsne3d_train.html"
)
# Out:
# Training silhouette score (cosine): 0.3321
# Saved interactive HTML to: /kaggle/working/tsne3d_train.html
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c9970c24-4b95-4f81-8cf9-9b030f2437b2" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9970c24-4b95-4f81-8cf9-9b030f2437b2")) {                    Plotly.newPlot(                        "c9970c24-4b95-4f81-8cf9-9b030f2437b2",                        [{"hovertemplate":"color=3\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"3","scene":"scene","showlegend":true,"x":[-2.511926,1.9346982,-0.4620476,2.7379453,1.9130341,1.0365363,2.668332,0.98325676,-0.71186155,0.4573424,2.5149572,-2.0267115,-4.153456,-3.489869,4.5062585,-7.291348,0.78515106,-1.1922748,-4.2580466,-2.2739985,2.485104,0.41440395,-3.328548,0.37190998,-8.620088,1.4347662,-1.542924,4.3144665,-2.422916,-2.567153,4.343874,-2.7999382,7.10496,-3.184124,6.573318,0.9878395,4.6633754,-6.294995,1.8455235,-2.9168987,-7.31107,-8.852665,-0.09083293,-8.468741,-3.5247102,4.0740743,-1.9430897,-1.2010514,-2.0885885,-2.1544714,1.1261317,-3.7941387,0.9868491,1.8922331,4.202912,-1.0717989,-4.750126,2.346985,-3.1789262,3.5809944,0.9648622,2.5974224,2.1269145,-4.1991744,-2.8380198,2.9655337,6.1717215,-2.8199012,-4.0211396,5.681382,1.9714084,5.54591,0.44137326,6.1740966,-2.1036131,5.180207,-8.548173,-8.093285,5.6498322,-1.4484158,1.1882045,1.809626,3.1225886,0.8002902,1.702024,-2.7173076,2.2361555,-2.2433984,-2.744023,-0.8517987,0.83427894,7.696761,-7.3561893,4.0142097,5.4728303,0.09257069,2.8286278,0.7355975,-1.2771174,4.4423213,0.7198606,5.5170555,1.0363411,0.20066608,-1.5328952,5.0912294,-3.9240816,-3.2523022,-2.4191048,-7.2386284,-0.07563508,-8.362916,-0.72660524,6.1961513,4.4151416,2.078563,6.0666013,-0.7148041,1.3393195,2.002563,6.616079,1.3603603,-2.5493937,4.26522,3.5266397,2.3755958,0.27589345,4.039661,-7.088548,4.8125486,-4.6276674,-2.6081378,-0.8326585,-1.5362256,-6.1485004,6.890077,6.338214,0.26867393,-0.20437695,3.9501576,2.027846,-8.796564,-7.716085,2.1815653,4.234418,2.2360997,0.23872311,0.58693194,-1.7043937,-5.625457,10.562096,-2.3609138,4.567138,2.3839638,1.0015132,-0.0403296,2.7623644,-2.741417,-4.999626,6.509207,-5.6904163,-5.2074633,0.68413454,2.369731,-2.653846,-7.721116,1.3705094,-9.484832,0.87285364,3.3286796,1.6514527,1.4843235,-3.015126,-1.6075119,2.1939917,5.99715,0.90998155,-7.79596,0.14648725,-1.0310366,-2.4180422,1.3407885,-2.6642237,-8.322849,4.059186,-2.4395568,-4.9571695,5.8911304,4.5697465,-4.3177943,6.8073926,0.14572994,2.7021515,-1.781635,-0.91000354,0.6244154,5.0569663,-5.0637913,6.6494036,2.2502165,-3.149031,6.153012,2.8446214,-2.4810274,4.867474,4.4413567,5.4209757,5.6760325,-2.5129156,-0.52597123,5.4301558,-2.1807656,-5.3848515,0.63007134,-4.461966,4.4141765,-1.893934,3.3607953,-6.922124,-0.6840486,4.361474,-5.9734054,-0.27026466,-8.487248,2.4672518,1.8393348,-2.5365663,2.2187023,-2.0531893,4.2251954,1.7451103,5.072299,3.8169186,-1.3767313,4.4679875,-1.374587,4.21354,1.3877746,3.7379594,-8.544259,-0.44608477,4.0631156,6.3913164,5.2097335,3.8856957,4.649516,-2.7743864,5.4564605,3.5672865,1.7679217,6.5016146,2.619538,0.310535,2.7877843,4.9232564,-9.203876,-0.5053997,7.249355,-2.9041288,2.7098749,6.7179103,1.6339151,0.13360865,1.5182273,4.690449,-0.32375628,-2.3699756,1.6045221,-5.101877,2.0395675,0.052940425,-2.390065,2.6213386,3.221348,-2.9940622,7.221507,2.8869529,-1.8106803,-4.165521,-4.4871054,1.8166457,-0.0015275624,-7.6731954,5.673762,-0.2774189,-1.4380594,-7.872402,-3.9219854,-7.9044375,-8.197552,-3.4988048,-3.9631436,3.6659977,4.091735,0.3207387,1.6617632,-2.5288637,0.8033869,-3.6361837,1.2470051,-0.40007618,2.7303607,-1.1198815,-7.5214515,0.06760148,-0.17252587,-5.235654,0.32090902,3.0274 ...

# %%
# TEST set clusters (frozen encoder)
test_feats, test_labels = extract_features(encoder, test_cls_loader, device=DEVICE)
print(f"Test silhouette score (cosine): {silhouette_cosine(test_feats, test_labels):.4f}")

tsne_plot_3d(
    test_feats, test_labels,
    title="3D t-SNE (test features)",
    perplexity=30, max_points=5000, seed=42,
    save_html="/kaggle/working/tsne3d_test.html"
)
# Out:
# Test silhouette score (cosine): 0.3529
# Saved interactive HTML to: /kaggle/working/tsne3d_test.html
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f81fc9a-a01f-4afd-8f43-099dab6feed4" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f81fc9a-a01f-4afd-8f43-099dab6feed4")) {                    Plotly.newPlot(                        "5f81fc9a-a01f-4afd-8f43-099dab6feed4",                        [{"hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":[-2.9606624,-11.016241,-11.161287,-11.705485,-4.1936417,-7.0582223,-7.204089,-6.1329355,-2.466151,-1.7298632,-6.85085,-4.0794177,-5.826632,-1.9042877,-6.730321,-10.553605,-11.749979,-3.167558,-2.529163,-3.247043,-8.390707,-3.9709115,-6.482594,-6.0008993,-1.4235071,-1.1621346,-2.3204584,-5.936648,-7.513893,-2.0278425,-1.8427044,-7.4789653,-4.7049465,-3.3696706,-3.2603264,-2.1193376,-5.7391677,-5.1522865,-10.336399,-3.1939654,-7.564714,1.8597233,-3.7193158,-5.5632095,-2.9331675,-7.253055,-2.9045348,-6.541662,-11.834406,-3.3910987,-1.5457246,-2.8676467,-3.6170208,-9.688096,-9.840149,8.461325,-8.518415,-3.7953424,-4.1984186,-2.8186073,-7.4172945,-2.0443437,-4.0905185,-10.896311,-9.49692,-7.152913,-2.006377,-6.2663107,-8.330486,-11.1132345,-7.2192445,-6.9479012,-6.287754,-4.847468,-3.51654,-2.7659707,-5.879852,-8.955182,-4.881918,-3.4946914,-10.674316,-4.326485,-5.5382853,-4.9639196,-3.7499597,-2.6623392,-1.1024679,-5.2507706,-5.8920174,-3.3136456,-3.3124113,-10.521174,-3.029434,-4.747923,-7.3632755,-6.08297,-4.56799,-5.5471816,-7.3800397,-3.5212877,-8.47829,-5.8703265,-3.2697713,-2.632009,-3.360867,-7.959942,-3.5438762,-11.2605915,-8.885678,-7.3519387,-1.8535016,-11.088963,-3.446839,-3.845159,-3.804428,-4.339855,-7.1803436,-7.3337684,-4.7224803,-7.469625,-1.0630709,-6.679596,-1.1481328,-1.5579802,0.6654991,-1.916643,-3.6709626,-10.246011,-10.216984,-2.199069,-3.1154878,-2.783336,-6.0388656,-9.808804,-3.438288,-7.517535,-7.022047,-5.123211,-3.8893063,-2.8486633,-8.946495,-1.0494831,-3.0987418,-7.325176,-1.9994129,-1.169305,-2.5098245,-11.826025,-5.1541247,-5.6549134,-7.396205,-4.922145,-2.2323744,-5.816725,-2.3682685,-7.0214887,-8.158606,-11.501756,-1.1702256,-11.149637,-2.935456,-2.7020946,-2.744091,-1.2671578,-1.1768739,-4.1422834,-8.684584,-3.054344,-7.3218203,-2.7252057,-6.5423126,-11.864362,-3.3908894,-11.883117,-1.7457556,-4.3677964,-9.754187,-10.016041,-1.2746505,-11.140165,-7.464485,-1.5397508,-3.623067,-7.6411457,-4.375489,-3.2039611,-3.0411627,-3.7299697,-5.7046137,2.8515818,-2.6127963,-3.458176,-1.4616054,-5.4930468,-2.5283604,-5.709041,-8.870597,-5.756205,-3.8185215,-2.0573056,-4.271184,-1.1981237,-2.013803,-6.990473,-8.197149,-5.8575473,-3.9587193,-5.63643,-10.3636265,-9.088566,-2.2494075,-3.6581972,-2.6766183,-2.5400548,-3.154592,-11.641588,-7.32079,-9.424372,-4.9541855,-10.634495,-1.5975896,-3.1554098,-4.441811,-3.2195983,-6.213316,-8.039353,-10.7522545,-6.376767,-3.170546,-4.7524524,-3.618992,-3.2897615,-7.2626576,-7.469404,-7.671961,-3.1268218,-2.6025765,-11.7833805,-5.9911113,-5.5287004,-1.1807345,-7.8868923,-11.628052,-8.062929,-9.070867,-9.468317,-8.316657,-12.012867,-4.1870666,-10.749224,-9.281846,-3.0098903,-9.706378,1.6172239,-3.9057312,-4.4856935,-2.9581969,-3.4431565,-5.756824,-9.593648,-10.809511,-1.7956336,-1.5956025,-2.383569,-5.318293,0.093567185,-6.104126,-8.544525,-6.013338,-9.922907,-8.338929,-7.4576025,-11.7647,-4.7959976,-3.793191,-8.38634,-3.2876067,-2.068019,-1.8393424,-8.717912,-5.9741945,-8.4366865,-3.5498981,-10.838192,-7.4376836,-2.726038,-3.3368015,-2.8400955,-11.016652,-2.8516886,-7.359484,-2.4971504,-3.5364616,-5.7666407,-6.553945,-2.760161,-1.1945702,-9.89362,-5.5244694,-9 ...
