# %%
# ================================
# BYOL Step 1: Imports
# ================================
import os, math, time, warnings
from pathlib import Path

import random   
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split

import torchvision
from torchvision import transforms as T, models

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
import plotly.express as px

from contextlib import nullcontext
from torch.amp import GradScaler, autocast  # modern API

# %%
# ================================
# BYOL Step 2: Config & Paths (FIXED)
# ================================
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# CSVs are inside EuroSAT folder (same as images)
CSV_ROOT = "/kaggle/input/eurosat-dataset/EuroSAT"
IMG_ROOT = "/kaggle/input/eurosat-dataset/EuroSAT"

TRAIN_CSV = "train.csv"
VAL_CSV   = "validation.csv"
TEST_CSV  = "test.csv"

IMG_SIZE = 224
BATCH_SIZE_PRETRAIN = 64
EPOCHS_PRETRAIN = 300
LR_PRETRAIN = 3e-4
PROJ_DIM = 128

BATCH_SIZE_LINEAR = 64
EPOCHS_LINEAR = 300
LR_LINEAR = 1e-3

print("Device:", DEVICE)
print(f"Device: {DEVICE.type}")
print(f"IMG_ROOT: {IMG_ROOT}")
print(f"CSV_ROOT: {CSV_ROOT}")
print(f"Splits: {TRAIN_CSV} {VAL_CSV} {TEST_CSV}")
# Out:
# Device: cuda
# Device: cuda
# IMG_ROOT: /kaggle/input/eurosat-dataset/EuroSAT
# CSV_ROOT: /kaggle/input/eurosat-dataset/EuroSAT
# Splits: train.csv validation.csv test.csv

# %%
# ================================
# BYOL Step 3: CSV Loading (as before)
# ================================
def _pick_col(df, candidates):
    lower = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand in df.columns: return cand
        if cand.lower() in lower: return lower[cand.lower()]
    return None

def _fix_one_path(p: str, img_root: str):
    p = str(p).strip()
    if os.path.exists(p): return p
    cand = os.path.join(img_root, p.lstrip("/"))
    if os.path.exists(cand): return cand
    if p.startswith("/kaggle/input/"):
        parts = p.split("/")
        try:
            newp = os.path.join(img_root, "/".join(parts[4:]))
            if os.path.exists(newp): return newp
        except Exception:
            pass
    return cand

def _infer_path_from_parts(row, img_root, filename_col=None, class_col=None):
    fname = str(row[filename_col]).strip() if filename_col else None
    cname = str(row[class_col]).strip() if class_col else None
    cands = []
    if fname:
        cands.append(os.path.join(img_root, fname))
        if class_col:
            cands.append(os.path.join(img_root, cname, fname))
            cands.append(os.path.join(img_root, cname.lower(), fname))
            cands.append(os.path.join(img_root, cname.capitalize(), fname))
    for c in cands:
        if os.path.exists(c): return c
    return cands[0] if cands else None

def load_split(csv_root: str, csv_name: str, img_root: str):
    csv_path = os.path.join(csv_root, csv_name)
    df = pd.read_csv(csv_path)

    if "Unnamed: 0" in df.columns:
        df = df.drop(columns=["Unnamed: 0"])

    path_col     = _pick_col(df, ["path", "filepath", "image", "image_path", "file"])
    filename_col = _pick_col(df, ["filename", "file_name", "image_id"])
    class_col    = _pick_col(df, ["classname", "class_name", "class", "category"])
    label_col    = _pick_col(df, ["label", "labels", "target", "y", "Label"])

    if path_col:
        df["path_fixed"] = df[path_col].apply(lambda p: _fix_one_path(p, img_root))
    elif filename_col:
        df["path_fixed"] = df.apply(lambda r: _infer_path_from_parts(r, img_root, filename_col, class_col), axis=1)
    else:
        raise ValueError(f"No path-like column found. Available: {list(df.columns)}.")

    if label_col is not None:
        if np.issubdtype(df[label_col].dtype, np.number):
            df["label_fixed"] = df[label_col].astype(int)
        else:
            df["label_fixed"] = pd.Categorical(df[label_col]).codes
    elif class_col is not None:
        df["label_fixed"] = pd.Categorical(df[class_col]).codes
    else:
        raise ValueError(f"No label-like column found. Available: {list(df.columns)}.")

    out = df[["path_fixed", "label_fixed"]].rename(columns={"path_fixed":"path","label_fixed":"label"})
    print(out.head())
    return out

# Load with corrected roots
train_df = load_split(CSV_ROOT, TRAIN_CSV, IMG_ROOT)
val_df   = load_split(CSV_ROOT, VAL_CSV,   IMG_ROOT)
test_df  = load_split(CSV_ROOT, TEST_CSV,  IMG_ROOT)

num_classes = int(max(train_df["label"].max(), val_df["label"].max(), test_df["label"].max()) + 1)
print(f"Loaded splits — train: {len(train_df)}, val: {len(val_df)}, test: {len(test_df)}, classes: {num_classes}")
# Out:
#                                                 path  label
# 0  /kaggle/input/eurosat-dataset/EuroSAT/AnnualCr...      0
# 1  /kaggle/input/eurosat-dataset/EuroSAT/Herbaceo...      2
# 2  /kaggle/input/eurosat-dataset/EuroSAT/Permanen...      6
# 3  /kaggle/input/eurosat-dataset/EuroSAT/Industri...      4
# 4  /kaggle/input/eurosat-dataset/EuroSAT/Herbaceo...      2
#                                                 path  label
# 0  /kaggle/input/eurosat-dataset/EuroSAT/Pasture/...      5
# 1  /kaggle/input/eurosat-dataset/EuroSAT/Forest/F...      1
# 2  /kaggle/input/eurosat-dataset/EuroSAT/Highway/...      3
# 3  /kaggle/input/eurosat-dataset/EuroSAT/River/Ri...      8
# 4  /kaggle/input/eurosat-dataset/EuroSAT/SeaLake/...      9
#                                                 path  label
# 0  /kaggle/input/eurosat-dataset/EuroSAT/AnnualCr...      0
# 1  /kaggle/input/eurosat-dataset/EuroSAT/Resident...      7
# 2  /kaggle/input/eurosat-dataset/EuroSAT/Pasture/...      5
# 3  /kaggle/input/eurosat-dataset/EuroSAT/Resident...      7
# 4  /kaggle/input/eurosat-dataset/EuroSAT/Pasture/...      5
# Loaded splits — train: 18900, val: 5400, test: 2700, classes: 10

# %%
# ================================
# BYOL Step 4: Per-class image count plots
# ================================
def _counts_bar(vc, title):
    plt.figure()
    xs = list(range(len(vc.index)))
    ys = [int(v) for v in vc.values]
    plt.bar(xs, ys)
    plt.xticks(xs, [str(i) for i in vc.index], rotation=0)
    plt.title(title)
    plt.xlabel("Class label")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

def show_split_counts(train_df, val_df, test_df):
    for name, df in [("Train", train_df), ("Val", val_df), ("Test", test_df)]:
        vc = df["label"].value_counts().sort_index()
        print(f"\n{name} per-class counts (label -> count)")
        for k, v in vc.items():
            print(f"{k}: {v}")
        _counts_bar(vc, f"{name} per-class counts")

show_split_counts(train_df, val_df, test_df)
# Out:
# Train per-class counts (label -> count)
# 0: 2100
# 1: 2100
# 2: 2100
# 3: 1750
# 4: 1750
# 5: 1400
# 6: 1750
# 7: 2100
# 8: 1750
# 9: 2100
# Val per-class counts (label -> count)
# 0: 600
# 1: 600
# 2: 600
# 3: 500
# 4: 500
# 5: 400
# 6: 500
# 7: 600
# 8: 500
# 9: 600
# Test per-class counts (label -> count)
# 0: 300
# 1: 300
# 2: 300
# 3: 250
# 4: 250
# 5: 200
# 6: 250
# 7: 300
# 8: 250
# 9: 300

# %%
# --- Augmentations for BYOL (two views of the same image) ---
class TransformBYOL:
    def __init__(self, size=IMG_SIZE):
        self.base = T.Compose([
            T.RandomResizedCrop(size=size, scale=(0.2, 1.0)),
            T.RandomHorizontalFlip(p=0.5),
            T.RandomApply([T.ColorJitter(0.4, 0.4, 0.2, 0.1)], p=0.8),
            T.RandomGrayscale(p=0.2),
            T.RandomApply([T.GaussianBlur(kernel_size=3)], p=0.5),
            T.ToTensor(),
            T.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225]),
        ])

    def __call__(self, x):
        # two independently augmented views
        q = self.base(x)
        k = self.base(x)
        return q, k

# Single-view transform (for linear eval features/classification)
class SingleTransform:
    def __init__(self, size=IMG_SIZE):
        self.t = T.Compose([
            T.Resize(int(size*1.14)),
            T.CenterCrop(size),
            T.ToTensor(),
            T.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225]),
        ])
    def __call__(self, x):
        return self.t(x)

# --- Datasets ---
class PairDataset(torch.utils.data.Dataset):
    """Returns two augmented views of the same image (BYOL pretraining)."""
    def __init__(self, df, transform_pair: TransformBYOL):
        self.df = df.reset_index(drop=True)
        self.transform_pair = transform_pair

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        p = self.df.loc[idx, "path"]
        img = Image.open(p).convert("RGB")
        v1, v2 = self.transform_pair(img)
        return v1, v2

class ClassifyDataset(torch.utils.data.Dataset):
    """Single view + label (for linear eval)."""
    def __init__(self, df, transform: SingleTransform):
        self.df = df.reset_index(drop=True)
        self.t = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        p  = self.df.loc[idx, "path"]
        y  = int(self.df.loc[idx, "label"])
        img = Image.open(p).convert("RGB")
        x = self.t(img)
        return x, y

# %%
# ================================
# BYOL Step 6: Dataloaders (Optimized)
# ================================
pair_tf   = TransformBYOL(IMG_SIZE)
single_tf = SingleTransform(IMG_SIZE)

train_pair_ds = PairDataset(train_df, pair_tf)
val_pair_ds   = PairDataset(val_df,   pair_tf)

train_pair_loader = DataLoader(
    train_pair_ds,
    batch_size=BATCH_SIZE_PRETRAIN,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True,
    prefetch_factor=4
)

val_pair_loader = DataLoader(
    val_pair_ds,
    batch_size=BATCH_SIZE_PRETRAIN,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True,
    prefetch_factor=4
)

train_cls_ds = ClassifyDataset(train_df, single_tf)
val_cls_ds   = ClassifyDataset(val_df,   single_tf)
test_cls_ds  = ClassifyDataset(test_df,  single_tf)

train_cls_loader = DataLoader(
    train_cls_ds,
    batch_size=BATCH_SIZE_LINEAR,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=4
)

val_cls_loader = DataLoader(
    val_cls_ds,
    batch_size=BATCH_SIZE_LINEAR,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=4
)

test_cls_loader = DataLoader(
    test_cls_ds,
    batch_size=BATCH_SIZE_LINEAR,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=4
)

print("PairDataset length:", len(train_pair_ds))
print("ClassifyDataset length:", len(train_cls_ds))
# Out:
# PairDataset length: 18900
# ClassifyDataset length: 18900

# %%
# ================================
# BYOL Step 7: Model (Encoder + Projection/Prediction + Target EMA)
# ================================
from copy import deepcopy

# --- Encoder (ResNet-50 backbone without final FC) ---
def build_encoder(pretrained: bool = False):
    # If you really want ImageNet weights, set pretrained=True.
    # BYOL pretraining usually starts from random init.
    enc = models.resnet50(weights=None if not pretrained else models.ResNet50_Weights.IMAGENET1K_V2)
    feat_dim = enc.fc.in_features
    enc.fc = nn.Identity()
    return enc, feat_dim

# --- Small helpers ---
class L2Norm(nn.Module):
    def __init__(self, dim=1, eps=1e-8):
        super().__init__()
        self.dim = dim
        self.eps = eps
    def forward(self, x):
        return F.normalize(x, dim=self.dim, eps=self.eps)

# --- Projection MLP (BYOL/SimCLR style) ---
class ProjectionHead(nn.Module):
    def __init__(self, in_dim, proj_dim=PROJ_DIM, hidden_dim=None):
        super().__init__()
        h = hidden_dim or in_dim
        self.net = nn.Sequential(
            nn.Linear(in_dim, h, bias=False),
            nn.BatchNorm1d(h),
            nn.ReLU(inplace=True),
            nn.Linear(h, proj_dim, bias=False),
            nn.BatchNorm1d(proj_dim, affine=False),  # output BN (no affine) as in SimCLR/BYOL
        )
        self.norm = L2Norm(dim=1)
    def forward(self, x):
        z = self.net(x)
        return self.norm(z)

# --- Prediction MLP (BYOL-specific) ---
class PredictionHead(nn.Module):
    def __init__(self, in_dim=PROJ_DIM, hidden_dim=None, out_dim=PROJ_DIM):
        super().__init__()
        h = hidden_dim or max(128, in_dim // 2)
        self.net = nn.Sequential(
            nn.Linear(in_dim, h, bias=False),
            nn.BatchNorm1d(h),
            nn.ReLU(inplace=True),
            nn.Linear(h, out_dim)
        )
        self.norm = L2Norm(dim=1)
    def forward(self, z):
        p = self.net(z)
        return self.norm(p)

# --- BYOL Online / Target Wrappers ---
class OnlineNet(nn.Module):
    def __init__(self, encoder, feat_dim, proj_dim=PROJ_DIM):
        super().__init__()
        self.encoder = encoder
        self.projector = ProjectionHead(feat_dim, proj_dim=proj_dim)
        self.predictor = PredictionHead(in_dim=proj_dim, out_dim=proj_dim)
    def forward(self, x):
        h = self.encoder(x)           # [B, feat_dim]
        z = self.projector(h)         # [B, proj_dim] (normalized)
        p = self.predictor(z)         # [B, proj_dim] (normalized)
        return p, z

class TargetNet(nn.Module):
    def __init__(self, encoder, feat_dim, proj_dim=PROJ_DIM):
        super().__init__()
        self.encoder = encoder
        self.projector = ProjectionHead(feat_dim, proj_dim=proj_dim)
        # target has no predictor; it supplies stop-grad "z"
        for p in self.parameters():
            p.requires_grad = False
    @torch.no_grad()
    def forward(self, x):
        h = self.encoder(x)
        z = self.projector(h)
        return z

# --- EMA utilities ---
@torch.no_grad()
def copy_params(src: nn.Module, dst: nn.Module):
    for p_s, p_d in zip(src.parameters(), dst.parameters()):
        p_d.data.copy_(p_s.data)

@torch.no_grad()
def momentum_update(target: nn.Module, online: nn.Module, m: float = 0.996):
    for p_t, p_o in zip(target.parameters(), online.parameters()):
        p_t.data = p_t.data * m + p_o.data * (1.0 - m)

# --- BYOL loss (symmetric cosine) ---
def byol_loss(p, z):
    # p, z are L2-normalized; stop-grad should be applied to z before calling this
    return 2 - 2 * F.cosine_similarity(p, z, dim=1).mean()

# --- Full BYOL module (manages online/target, forward computes loss) ---
class BYOL(nn.Module):
    def __init__(self, proj_dim=PROJ_DIM, momentum=0.996, pretrained_backbone=False):
        super().__init__()
        self.m = momentum

        # build online & target encoders
        enc_online, feat_dim = build_encoder(pretrained=pretrained_backbone)
        enc_target, _        = build_encoder(pretrained=pretrained_backbone)

        self.online  = OnlineNet(enc_online, feat_dim, proj_dim=proj_dim)
        self.target  = TargetNet(enc_target, feat_dim, proj_dim=proj_dim)

        # init target = online
        copy_params(self.online.encoder,   self.target.encoder)
        copy_params(self.online.projector, self.target.projector)

    @torch.no_grad()
    def update_target(self):
        momentum_update(self.target.encoder,   self.online.encoder,   m=self.m)
        momentum_update(self.target.projector, self.online.projector, m=self.m)

    def forward(self, x1, x2):
        # online predictions
        p1, z1_online = self.online(x1)
        p2, z2_online = self.online(x2)

        # target projections (stop-grad implicitly via nn.Module no-grad usage)
        with torch.no_grad():
            z1 = self.target(x1)
            z2 = self.target(x2)

        # symmetric BYOL loss
        loss = byol_loss(p1, z2.detach()) + byol_loss(p2, z1.detach())
        return loss, (p1, z1_online, p2, z2_online)

# %%
# ================================
# Step 8 — BYOL Pretraining (VAL_EVERY, clean warnings, decimal LR)
# ================================

warnings.filterwarnings("ignore", message=r".*lr_scheduler\.step.*optimizer\.step.*")

# --- knobs (use existing if already set) ---
LR = LR_PRETRAIN
WARMUP_FRAC = WARMUP_FRAC if 'WARMUP_FRAC' in globals() else 0.10
M_BASE  = M_BASE  if 'M_BASE'  in globals() else 0.996
M_FINAL = M_FINAL if 'M_FINAL' in globals() else 0.999
WEIGHT_DECAY = WEIGHT_DECAY if 'WEIGHT_DECAY' in globals() else 1e-4
VAL_EVERY = 2

# --- checkpoint paths ---
CKPT_LOAD_DIR = Path("/kaggle/input/byol-ckpts-v3")   # ← এখানে v3 লিখতে হবে
LAST_PRE_PATH_LOAD = str(CKPT_LOAD_DIR / "byol_pretrain_last.pth")
BEST_PRETRAIN_FULL_LOAD = str(CKPT_LOAD_DIR / "byol_pretrain_best_full.pth")


# Save new checkpoints (into working dir)
CKPT_SAVE_DIR = Path("/kaggle/working/byol_ckpts"); CKPT_SAVE_DIR.mkdir(parents=True, exist_ok=True)
BEST_ENC_PATH           = str(CKPT_SAVE_DIR / "byol_encoder_best.pth")
BEST_PRETRAIN_FULL_PATH = str(CKPT_SAVE_DIR / "byol_pretrain_best_full.pth")
LAST_PRE_PATH_SAVE      = str(CKPT_SAVE_DIR / "byol_pretrain_last.pth")

RESUME_PRETRAIN = True

# --- build model & optimizer (BYOL defined in Step 7) ---
proj_dim = PROJ_DIM if 'PROJ_DIM' in globals() else PROJECTION_DIM
byol = BYOL(proj_dim=proj_dim, momentum=M_BASE, pretrained_backbone=False).to(DEVICE)
opt  = optim.AdamW((p for p in byol.parameters() if p.requires_grad), lr=LR, weight_decay=WEIGHT_DECAY)

# --- cosine LR with warmup (per-step) ---
steps_per_epoch = max(1, len(train_pair_loader))
TOTAL_STEPS  = EPOCHS_PRETRAIN * steps_per_epoch
WARMUP_STEPS = max(1, int(WARMUP_FRAC * TOTAL_STEPS))
def lr_lambda(step):
    if step < WARMUP_STEPS:
        return (step + 1) / float(WARMUP_STEPS)
    t = (step - WARMUP_STEPS) / max(1, (TOTAL_STEPS - WARMUP_STEPS))
    return 0.5 * (1.0 + math.cos(math.pi * t))
scheduler = optim.lr_scheduler.LambdaLR(opt, lr_lambda=lr_lambda)

# --- EMA momentum schedule ---
def ema_m(step):
    t = min(1.0, step / max(1, TOTAL_STEPS))
    return M_BASE + (M_FINAL - M_BASE) * (0.5 * (1.0 + math.cos(math.pi * (1.0 - t))))

# --- AMP ---
USE_AMP = (DEVICE.type == "cuda")
scaler  = GradScaler("cuda", enabled=USE_AMP) if USE_AMP else GradScaler(enabled=False)

# --- bookkeeping / resume ---
hist = {"epoch": [], "train_loss": [], "val_loss": []}
best_val = float("inf"); start_epoch = 1; global_step = 0

if RESUME_PRETRAIN and os.path.exists(LAST_PRE_PATH_LOAD):
    ck = torch.load(LAST_PRE_PATH_LOAD, map_location="cpu")
    byol.load_state_dict(ck["model"]); opt.load_state_dict(ck["optimizer"])
    if "scheduler" in ck: scheduler.load_state_dict(ck["scheduler"])
    hist = ck.get("hist", hist); best_val = ck.get("best_val", best_val)
    start_epoch = ck.get("epoch", 0) + 1; global_step = ck.get("global_step", 0)
    print(f"✅ Resumed BYOL from LAST checkpoint (epoch {start_epoch}, global_step={global_step})")
elif RESUME_PRETRAIN and os.path.exists(BEST_PRETRAIN_FULL_LOAD):
    ck = torch.load(BEST_PRETRAIN_FULL_LOAD, map_location="cpu")
    byol.load_state_dict(ck["model"]); opt.load_state_dict(ck["optimizer"])
    if "scheduler" in ck: scheduler.load_state_dict(ck["scheduler"])
    hist = ck.get("hist", hist); best_val = ck.get("best_val", best_val)
    start_epoch = ck.get("epoch", 0) + 1; global_step = ck.get("global_step", 0)
    print(f"✅ Resumed BYOL from BEST checkpoint (epoch {start_epoch}, global_step={global_step})")
else:
    print("🚀 Starting BYOL training fresh")

# --- training loop ---
def run_epoch(loader, train=True, epoch_idx=1):
    global global_step
    byol.train(mode=train)
    total, n = 0.0, 0
    for i, (x1, x2) in enumerate(loader, start=1):
        x1 = x1.to(DEVICE, non_blocking=True); x2 = x2.to(DEVICE, non_blocking=True)
        ctx = autocast("cuda", dtype=torch.float16) if USE_AMP else nullcontext()
        if train:
            opt.zero_grad(set_to_none=True)
            with ctx:
                loss, _ = byol(x1, x2)
            scaler.scale(loss).backward()
            torch.nn.utils.clip_grad_norm_(byol.parameters(), max_norm=1.0)
            scaler.step(opt); scaler.update()
            scheduler.step()
            byol.m = ema_m(global_step); byol.update_target()
            global_step += 1
        else:
            with torch.no_grad(), ctx:
                loss, _ = byol(x1, x2)
        bs = x1.size(0); total += float(loss.item()) * bs; n += bs
    return total / max(1, n)

for epoch in range(start_epoch, EPOCHS_PRETRAIN + 1):
    t0 = time.time()
    train_loss = run_epoch(train_pair_loader, train=True, epoch_idx=epoch)
    val_loss = run_epoch(val_pair_loader, train=False, epoch_idx=epoch) if (epoch % VAL_EVERY == 0) else float("nan")

    hist["epoch"].append(epoch); hist["train_loss"].append(train_loss); hist["val_loss"].append(val_loss)

    cur_lr = float(opt.param_groups[0]["lr"])
    cur_m  = float(byol.m)

    # Save BEST (only when val ran)
    if not math.isnan(val_loss) and val_loss < best_val - 1e-6:
        best_val = val_loss
        torch.save({"online_encoder": byol.online.encoder.state_dict(),
                    "online_projector": byol.online.projector.state_dict(),
                    "epoch": epoch, "best_val": best_val}, BEST_ENC_PATH)
        torch.save({"model": byol.state_dict(), "optimizer": opt.state_dict(),
                    "scheduler": scheduler.state_dict(), "hist": hist,
                    "epoch": epoch, "best_val": best_val,
                    "global_step": global_step}, BEST_PRETRAIN_FULL_PATH)
        print(f"✅ Saved BEST (epoch={epoch})")

    # Always save LAST
    torch.save({"model": byol.state_dict(), "optimizer": opt.state_dict(),
                "scheduler": scheduler.state_dict(), "hist": hist,
                "epoch": epoch, "best_val": best_val,
                "global_step": global_step}, LAST_PRE_PATH_SAVE)

    print(f"[epoch {epoch:03d}] train_loss={train_loss:.4f} "
          f"val_loss={val_loss:.4f} lr={cur_lr:.8f} m={cur_m:.6f} "
          f"({time.time() - t0:.1f}s)")
# Out:
# ✅ Resumed BYOL from LAST checkpoint (epoch 201, global_step=59000)
# [epoch 201] train_loss=0.1933 val_loss=nan lr=0.00008899 m=0.998264 (215.2s)
# [epoch 202] train_loss=0.1971 val_loss=0.1787 lr=0.00008740 m=0.998277 (261.4s)
# [epoch 203] train_loss=0.1964 val_loss=nan lr=0.00008582 m=0.998290 (212.4s)
# [epoch 204] train_loss=0.1956 val_loss=0.1745 lr=0.00008424 m=0.998304 (256.3s)
# [epoch 205] train_loss=0.1931 val_loss=nan lr=0.00008268 m=0.998317 (212.8s)
# [epoch 206] train_loss=0.1952 val_loss=0.1738 lr=0.00008113 m=0.998330 (255.4s)
# [epoch 207] train_loss=0.1919 val_loss=nan lr=0.00007958 m=0.998343 (212.6s)
# [epoch 208] train_loss=0.1910 val_loss=0.1749 lr=0.00007804 m=0.998356 (256.2s)
# [epoch 209] train_loss=0.1871 val_loss=nan lr=0.00007652 m=0.998369 (212.6s)
# [epoch 210] train_loss=0.1920 val_loss=0.1730 lr=0.00007500 m=0.998382 (254.6s)
# [epoch 211] train_loss=0.1902 val_loss=nan lr=0.00007349 m=0.998394 (212.8s)
# [epoch 212] train_loss=0.1915 val_loss=0.1826 lr=0.00007200 m=0.998407 (254.4s)
# [epoch 213] train_loss=0.1896 val_loss=nan lr=0.00007051 m=0.998419 (212.7s)
# [epoch 214] train_loss=0.1910 val_loss=0.1752 lr=0.00006904 m=0.998432 (255.2s)
# [epoch 215] train_loss=0.1895 val_loss=nan lr=0.00006757 m=0.998444 (212.6s)
# [epoch 216] train_loss=0.1900 val_loss=0.1797 lr=0.00006612 m=0.998456 (256.6s)
# [epoch 217] train_loss=0.1925 val_loss=nan lr=0.00006468 m=0.998468 (213.0s)
# [epoch 218] train_loss=0.1903 val_loss=0.1778 lr=0.00006325 m=0.998480 (254.5s)
# [epoch 219] train_loss=0.1895 val_loss=nan lr=0.00006183 m=0.998492 (212.4s)
# ✅ Saved BEST (epoch=220)
# [epoch 220] train_loss=0.1844 val_loss=0.1690 lr=0.00006043 m=0.998504 (256.0s)
# [epoch 221] train_loss=0.1880 val_loss=nan lr=0.00005903 m=0.998515 (212.6s)
# [epoch 222] train_loss=0.1889 val_loss=0.1715 lr=0.00005765 m=0.998527 (254.5s)
# [epoch 223] train_loss=0.1854 val_loss=nan lr=0.00005628 m=0.998538 (212.4s)
# [epoch 224] train_loss=0.1868 val_loss=0.1699 lr=0.00005493 m=0.998549 (254.4s)
# [epoch 225] train_loss=0.1838 val_loss=nan lr=0.00005358 m=0.998561 (212.5s)
# [epoch 226] train_loss=0.1867 val_loss=0.1709 lr=0.00005225 m=0.998572 (254.1s)
# [epoch 227] train_loss=0.1848 val_loss=nan lr=0.00005093 m=0.998583 (212.5s)
# [epoch 228] train_loss=0.1826 val_loss=0.1711 lr=0.00004963 m=0.998593 (254.3s)
# [epoch 229] train_loss=0.1817 val_loss=nan lr=0.00004834 m=0.998604 (212.2s)
# [epoch 230] train_loss=0.1857 val_loss=0.1713 lr=0.00004706 m=0.998615 (254.7s)
# [epoch 231] train_loss=0.1855 val_loss=nan lr=0.00004580 m=0.998625 (212.3s)
# [epoch 232] train_loss=0.1826 val_loss=0.1765 lr=0.00004455 m=0.998635 (253.7s)
# [epoch 233] train_loss=0.1851 val_loss=nan lr=0.00004332 m=0.998646 (212.1s)
# [epoch 234] train_loss=0.1804 val_loss=0.1778 lr=0.00004210 m=0.998656 (253.5s)
# [epoch 235] train_loss=0.1865 val_loss=nan lr=0.00004089 m=0.998666 (212.0s)
# [epoch 236] train_loss=0.1810 val_loss=0.1703 lr=0.00003970 m=0.998676 (253.7s)
# [epoch 237] train_loss=0.1791 val_loss=nan lr=0.00003853 m=0.998685 (212.1s)
# [epoch 238] train_loss=0.1806 val_loss=0.1707 lr=0.00003737 m=0.998695 (253.0s)
# [epoch 239] train_loss=0.1796 val_loss=nan lr=0.00003622 m=0.998704 (212.4s)
# [epoch 240] train_loss=0.1782 val_loss=0.1707 lr=0.00003509 m=0.998713 (254.0s)
# [epoch 241] train_loss=0.1802 val_loss=nan lr=0.00003398 m=0.998723 (212.4s)
# ✅ Saved BEST (epoch=242)
# [epoch 242] train_loss=0.1796 val_loss=0.1677 lr=0.00003288 m=0.998732 (255.5s)
# [epoch 243] train_loss=0.1816 val_loss=nan lr=0.00003180 m=0.998741 (212.5s)
# [epoch 244] train_loss=0.1798 val_loss=0.1725 lr=0.00003073 m=0.998749 (254.6s)
# [epoch 245] train_loss=0.1766 val_loss=nan lr=0.00002968 m=0.998758 (212.5s)
# ✅ Saved BEST (epoch=246)
# [epoch 246] train_loss=0.1752 val_loss=0.1632 lr=0.00002865 m=0.998766 (256.5s)
# [epoch 247] train_loss=0.1790 val_loss=nan lr=0.00002763 m=0.998775 (212.7s)
# [epoch 248] train_loss=0.1772 val_loss=0.1672 lr=0.00002663 m=0.998783 (256.8s)
# [epoch 249] train_loss=0.1795 val_loss=nan lr=0.00002564 m=0.998791 (212.4s)
# [epoch 250] train_loss=0.1813 val_loss=0.1694 lr=0.00002468 m=0.998799 (255.5s)
# [epoch 251] train_loss=0.1751 val_loss=nan lr=0.00002373 m=0.998807 (212.6s)
# ✅ Saved BEST (epoch=252)
# [epoch 252] train_loss=0.1757 val_loss=0.1627 lr=0.00002279 m=0.998814 (257.2s)
# [epoch 253] train_loss=0.1788 val_loss=nan lr=0.00002188 m=0.998822 (212.7s)
# [epoch 254] train_loss=0.1747 val_loss=0.1638 lr=0.00002098 m=0.998829 (256.0s)
# [epoch 255] train_loss=0.1754 val_loss=nan lr=0.00002010 m=0.998836 (212.8s)
# [epoch 256] train_loss=0.1766 val_loss=0.1665 lr=0.00001923 m=0.998844 (255.2s)
# [epoch 257] train_loss=0.1793 val_loss=nan lr=0.00001839 m=0.998850 (212.6s)
# [epoch 258] train_loss=0.1733 val_loss=0.1641 lr=0.00001756 m=0.998857 (255.6s)
# [epoch 259] train_loss=0.1747 val_loss=nan lr=0.00001675 m=0.998864 (212.5s)
# [epoch 260] train_loss=0.1733 val_loss=0.1677 lr=0.00001596 m=0.998870 (255.3s)
# [epoch 261] train_loss=0.1752 val_loss=nan lr=0.00001518 m=0.998877 (212.6s)
# [epoch 262] train_loss=0.1743 val_loss=0.1632 lr=0.00001442 m=0.998883 (254.9s)
# [epoch 263] train_loss=0.1728 val_loss=nan lr=0.00001369 m=0.998889 (212.6s)
# [epoch 264] train_loss=0.1748 val_loss=0.1736 lr=0.00001297 m=0.998895 (255.3s)
# [epoch 265] train_loss=0.1724 val_loss=nan lr=0.00001227 m=0.998900 (212.8s)
# [epoch 266] train_loss=0.1755 val_loss=0.1667 lr=0.00001159 m=0.998906 (255.1s)
# [epoch 267] train_loss=0.1709 val_loss=nan lr=0.00001092 m=0.998911 (212.7s)
# ✅ Saved BEST (epoch=268)
# [epoch 268] train_loss=0.1726 val_loss=0.1593 lr=0.00001028 m=0.998917 (256.4s)
# [epoch 269] train_loss=0.1695 val_loss=nan lr=0.00000965 m=0.998922 (212.6s)
# [epoch 270] train_loss=0.1736 val_loss=0.1680 lr=0.00000905 m=0.998927 (255.9s)
# [epoch 271] train_loss=0.1693 val_loss=nan lr=0.00000846 m=0.998931 (212.7s)
# [epoch 272] train_loss=0.1746 val_loss=0.1633 lr=0.00000789 m=0.998936 (255.1s)
# [epoch 273] train_loss=0.1748 val_loss=nan lr=0.00000734 m=0.998940 (212.5s)
# [epoch 274] train_loss=0.1738 val_loss=0.1625 lr=0.00000681 m=0.998945 (255.1s)
# [epoch 275] train_loss=0.1741 val_loss=nan lr=0.00000630 m=0.998949 (212.4s)
# [epoch 276] train_loss=0.1744 val_loss=0.1615 lr=0.00000581 m=0.998953 (255.0s)
# [epoch 277] train_loss=0.1730 val_loss=nan lr=0.00000534 m=0.998957 (213.0s)
# [epoch 278] train_loss=0.1731 val_loss=0.1636 lr=0.00000489 m=0.998960 (256.9s)
# [epoch 279] train_loss=0.1757 val_loss=nan lr=0.00000446 m=0.998964 (213.5s)
# ✅ Saved BEST (epoch=280)
# [epoch 280] train_loss=0.1695 val_loss=0.1585 lr=0.00000404 m=0.998967 (257.6s)
# [epoch 281] train_loss=0.1695 val_loss=nan lr=0.00000365 m=0.998970 (213.5s)
# [epoch 282] train_loss=0.1710 val_loss=0.1601 lr=0.00000328 m=0.998973 (255.3s)
# [epoch 283] train_loss=0.1722 val_loss=nan lr=0.00000292 m=0.998976 (212.7s)
# [epoch 284] train_loss=0.1714 val_loss=0.1598 lr=0.00000259 m=0.998979 (255.6s)
# [epoch 285] train_loss=0.1729 val_loss=nan lr=0.00000228 m=0.998982 (212.7s)
# [epoch 286] train_loss=0.1711 val_loss=0.1678 lr=0.00000199 m=0.998984 (255.3s)
# [epoch 287] train_loss=0.1704 val_loss=nan lr=0.00000171 m=0.998986 (212.5s)
# [epoch 288] train_loss=0.1704 val_loss=0.1673 lr=0.00000146 m=0.998988 (255.5s)
# [epoch 289] train_loss=0.1687 val_loss=nan lr=0.00000123 m=0.998990 (212.5s)
# [epoch 290] train_loss=0.1717 val_loss=0.1588 lr=0.00000101 m=0.998992 (255.7s)
# [epoch 291] train_loss=0.1699 val_loss=nan lr=0.00000082 m=0.998993 (212.8s)
# [epoch 292] train_loss=0.1692 val_loss=0.1659 lr=0.00000065 m=0.998995 (255.2s)
# [epoch 293] train_loss=0.1672 val_loss=nan lr=0.00000050 m=0.998996 (212.5s)
# [epoch 294] train_loss=0.1692 val_loss=0.1593 lr=0.00000037 m=0.998997 (255.5s)
# [epoch 295] train_loss=0.1666 val_loss=nan lr=0.00000025 m=0.998998 (212.4s)
# [epoch 296] train_loss=0.1682 val_loss=0.1647 lr=0.00000016 m=0.998999 (255.8s)
# [epoch 297] train_loss=0.1656 val_loss=nan lr=0.00000009 m=0.998999 (212.7s)
# [epoch 298] train_loss=0.1653 val_loss=0.1624 lr=0.00000004 m=0.999000 (255.8s)
# [epoch 299] train_loss=0.1630 val_loss=nan lr=0.00000001 m=0.999000 (212.5s)
# ✅ Saved BEST (epoch=300)
# [epoch 300] train_loss=0.1708 val_loss=0.1584 lr=0.00000000 m=0.999000 (256.1s)

# %%
ep = np.array(hist["epoch"], dtype=int)
tr = np.array(hist["train_loss"], dtype=float)
va = np.array(hist["val_loss"], dtype=float)

plt.figure(figsize=(7,4))
plt.plot(ep, tr, label="Train")
# val-এ NaN থাকলে (VAL_EVERY>1) স্কিপ করবো
if np.isfinite(va).any():
    m = np.isfinite(va)
    plt.plot(ep[m], va[m], label="Val")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Train 

BEST_ENC_PATH  = "/kaggle/working/byol_ckpts/byol_encoder_best.pth"   # from Step 8
BEST_HEAD_PATH = "/kaggle/working/byol_ckpts/byol_linear_head_best.pth"

# ---- helper: build the same backbone used for BYOL encoder (ResNet-50 features) ----
def build_encoder(pretrained=False):
    backbone = torchvision.models.resnet50(
        weights=None if not pretrained else torchvision.models.ResNet50_Weights.IMAGENET1K_V2
    )
    backbone.fc = nn.Identity()   # 2048-dim features
    FEAT_DIM = 2048
    return backbone, FEAT_DIM

# ---- 9A) rebuild encoder & load BYOL-pretrained weights, then freeze ----
encoder, FEAT_DIM = build_encoder(pretrained=False)
ck = torch.load(BEST_ENC_PATH, map_location="cpu")
missing = encoder.load_state_dict(ck["online_encoder"], strict=False)
print("Encoder load (missing/unexpected):", missing)

encoder = encoder.to(DEVICE).eval()
for p in encoder.parameters():
    p.requires_grad = False

# ---- 9B) linear head ----
num_classes = int(max(train_df["label"].max(), val_df["label"].max(), test_df["label"].max()) + 1)

class LinearHead(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.fc = nn.Linear(in_dim, out_dim)
    def forward(self, x):
        return self.fc(x)

head = LinearHead(FEAT_DIM, num_classes).to(DEVICE)
opt_lin = optim.Adam(head.parameters(), lr=LR_LINEAR)
crit = nn.CrossEntropyLoss()

# ---- history containers ----
lin_hist = {"epoch": [], "train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

# ---- 9C) one epoch (train/eval) ----
def linear_epoch(encoder, loader, train=True):
    head.train(mode=train)
    total_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(DEVICE, non_blocking=True), y.to(DEVICE, non_blocking=True)
        with torch.no_grad():
            feats = encoder(x)                 # [B, 2048]
        logits = head(feats)
        loss = crit(logits, y)

        if train:
            opt_lin.zero_grad(set_to_none=True)
            loss.backward()
            opt_lin.step()

        total_loss += loss.item() * x.size(0)
        pred = logits.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return total_loss / max(1,total), correct / max(1,total)

# ---- 9D) train linear head ----
best_val_acc = 0.0
for ep in range(1, EPOCHS_LINEAR + 1):
    tr_loss, tr_acc = linear_epoch(encoder, train_cls_loader, train=True)
    va_loss, va_acc = linear_epoch(encoder, val_cls_loader,   train=False)

    # log history
    lin_hist["epoch"].append(ep)
    lin_hist["train_loss"].append(tr_loss)
    lin_hist["train_acc"].append(tr_acc * 100.0)  # store as %
    lin_hist["val_loss"].append(va_loss)
    lin_hist["val_acc"].append(va_acc * 100.0)    # store as %

    # save best head
    if va_acc > best_val_acc + 1e-6:
        best_val_acc = va_acc
        torch.save(
            {"state_dict": head.state_dict(), "feat_dim": FEAT_DIM, "num_classes": num_classes},
            BEST_HEAD_PATH
        )
        print(f"[Linear {ep}] ✅ Saved best head -> {BEST_HEAD_PATH}")

    print(f"[Linear {ep:02d}] "
          f"train: loss={tr_loss:.4f}, acc={tr_acc*100:.2f}% | "
          f"val: loss={va_loss:.4f}, acc={va_acc*100:.2f}%")
# Out:
# Encoder load (missing/unexpected): <All keys matched successfully>
# [Linear 1] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 01] train: loss=0.4109, acc=85.88% | val: loss=0.3568, acc=88.09%
# [Linear 02] train: loss=0.3136, acc=89.40% | val: loss=0.3974, acc=87.22%
# [Linear 3] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 03] train: loss=0.2769, acc=90.65% | val: loss=0.3270, acc=88.98%
# [Linear 04] train: loss=0.2683, acc=90.87% | val: loss=0.3581, acc=88.31%
# [Linear 5] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 05] train: loss=0.2567, acc=91.17% | val: loss=0.2834, acc=90.83%
# [Linear 6] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 06] train: loss=0.2461, acc=91.47% | val: loss=0.2578, acc=91.17%
# [Linear 7] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 07] train: loss=0.2418, acc=91.86% | val: loss=0.2496, acc=92.22%
# [Linear 08] train: loss=0.2298, acc=92.19% | val: loss=0.2515, acc=91.46%
# [Linear 9] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 09] train: loss=0.2225, acc=92.44% | val: loss=0.2402, acc=92.28%
# [Linear 10] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 10] train: loss=0.2228, acc=92.53% | val: loss=0.2404, acc=92.30%
# [Linear 11] train: loss=0.2175, acc=92.40% | val: loss=0.2315, acc=92.26%
# [Linear 12] train: loss=0.2139, acc=92.79% | val: loss=0.2692, acc=91.43%
# [Linear 13] train: loss=0.2141, acc=92.95% | val: loss=0.2566, acc=91.50%
# [Linear 14] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 14] train: loss=0.2030, acc=93.13% | val: loss=0.2184, acc=92.59%
# [Linear 15] train: loss=0.1941, acc=93.27% | val: loss=0.2839, acc=90.74%
# [Linear 16] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 16] train: loss=0.1972, acc=93.23% | val: loss=0.2233, acc=92.61%
# [Linear 17] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 17] train: loss=0.1918, acc=93.58% | val: loss=0.2110, acc=93.33%
# [Linear 18] train: loss=0.1986, acc=93.37% | val: loss=0.2415, acc=92.24%
# [Linear 19] train: loss=0.1900, acc=93.85% | val: loss=0.2659, acc=91.54%
# [Linear 20] train: loss=0.1941, acc=93.48% | val: loss=0.2451, acc=92.24%
# [Linear 21] train: loss=0.1855, acc=93.74% | val: loss=0.2049, acc=93.13%
# [Linear 22] train: loss=0.1915, acc=93.53% | val: loss=0.2570, acc=91.52%
# [Linear 23] train: loss=0.1881, acc=93.58% | val: loss=0.2086, acc=92.98%
# [Linear 24] train: loss=0.1749, acc=94.07% | val: loss=0.2618, acc=92.04%
# [Linear 25] train: loss=0.1788, acc=93.94% | val: loss=0.2165, acc=93.09%
# [Linear 26] train: loss=0.1851, acc=93.65% | val: loss=0.2886, acc=91.19%
# [Linear 27] train: loss=0.1728, acc=93.88% | val: loss=0.2625, acc=91.81%
# [Linear 28] train: loss=0.1885, acc=93.63% | val: loss=0.2371, acc=92.85%
# [Linear 29] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 29] train: loss=0.1709, acc=94.02% | val: loss=0.1936, acc=93.50%
# [Linear 30] train: loss=0.1779, acc=93.87% | val: loss=0.2185, acc=93.09%
# [Linear 31] train: loss=0.1801, acc=93.96% | val: loss=0.2068, acc=93.46%
# [Linear 32] train: loss=0.1665, acc=94.33% | val: loss=0.2877, acc=91.41%
# [Linear 33] train: loss=0.1730, acc=94.16% | val: loss=0.2798, acc=91.30%
# [Linear 34] train: loss=0.1599, acc=94.63% | val: loss=0.2532, acc=91.89%
# [Linear 35] train: loss=0.1565, acc=94.59% | val: loss=0.2045, acc=93.37%
# [Linear 36] train: loss=0.1567, acc=94.56% | val: loss=0.2262, acc=93.11%
# [Linear 37] train: loss=0.1557, acc=94.54% | val: loss=0.2093, acc=93.13%
# [Linear 38] train: loss=0.1631, acc=94.46% | val: loss=0.2138, acc=93.20%
# [Linear 39] train: loss=0.1573, acc=94.52% | val: loss=0.2095, acc=93.39%
# [Linear 40] train: loss=0.1512, acc=94.83% | val: loss=0.2856, acc=90.78%
# [Linear 41] train: loss=0.1535, acc=94.70% | val: loss=0.2249, acc=93.09%
# [Linear 42] train: loss=0.1534, acc=94.69% | val: loss=0.2153, acc=93.06%
# [Linear 43] train: loss=0.1483, acc=95.05% | val: loss=0.2340, acc=92.52%
# [Linear 44] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 44] train: loss=0.1517, acc=94.71% | val: loss=0.1978, acc=93.87%
# [Linear 45] train: loss=0.1416, acc=95.07% | val: loss=0.2376, acc=92.85%
# [Linear 46] train: loss=0.1570, acc=94.68% | val: loss=0.2566, acc=92.30%
# [Linear 47] train: loss=0.1444, acc=94.92% | val: loss=0.1974, acc=93.26%
# [Linear 48] train: loss=0.1470, acc=94.90% | val: loss=0.2266, acc=92.98%
# [Linear 49] train: loss=0.1446, acc=94.92% | val: loss=0.2261, acc=93.30%
# [Linear 50] train: loss=0.1477, acc=94.80% | val: loss=0.2259, acc=92.85%
# [Linear 51] train: loss=0.1363, acc=95.26% | val: loss=0.2454, acc=92.44%
# [Linear 52] train: loss=0.1400, acc=95.20% | val: loss=0.2135, acc=93.50%
# [Linear 53] train: loss=0.1344, acc=95.37% | val: loss=0.1997, acc=93.57%
# [Linear 54] train: loss=0.1316, acc=95.47% | val: loss=0.2553, acc=92.13%
# [Linear 55] train: loss=0.1451, acc=94.97% | val: loss=0.1989, acc=93.46%
# [Linear 56] train: loss=0.1395, acc=95.20% | val: loss=0.2021, acc=93.37%
# [Linear 57] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 57] train: loss=0.1293, acc=95.46% | val: loss=0.1949, acc=93.89%
# [Linear 58] train: loss=0.1383, acc=95.20% | val: loss=0.2059, acc=93.48%
# [Linear 59] train: loss=0.1273, acc=95.69% | val: loss=0.2353, acc=93.04%
# [Linear 60] train: loss=0.1336, acc=95.28% | val: loss=0.1934, acc=93.63%
# [Linear 61] train: loss=0.1310, acc=95.50% | val: loss=0.2581, acc=92.17%
# [Linear 62] train: loss=0.1306, acc=95.40% | val: loss=0.2485, acc=91.69%
# [Linear 63] train: loss=0.1329, acc=95.36% | val: loss=0.2015, acc=93.52%
# [Linear 64] train: loss=0.1262, acc=95.57% | val: loss=0.2231, acc=93.00%
# [Linear 65] train: loss=0.1252, acc=95.49% | val: loss=0.2219, acc=93.02%
# [Linear 66] train: loss=0.1265, acc=95.61% | val: loss=0.2263, acc=92.72%
# [Linear 67] train: loss=0.1227, acc=95.62% | val: loss=0.2270, acc=92.94%
# [Linear 68] train: loss=0.1248, acc=95.50% | val: loss=0.2303, acc=92.96%
# [Linear 69] train: loss=0.1227, acc=95.60% | val: loss=0.2251, acc=93.02%
# [Linear 70] train: loss=0.1254, acc=95.50% | val: loss=0.2482, acc=92.94%
# [Linear 71] train: loss=0.1193, acc=95.82% | val: loss=0.2731, acc=91.46%
# [Linear 72] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 72] train: loss=0.1287, acc=95.35% | val: loss=0.1962, acc=94.09%
# [Linear 73] train: loss=0.1277, acc=95.38% | val: loss=0.2111, acc=93.61%
# [Linear 74] train: loss=0.1195, acc=95.87% | val: loss=0.2005, acc=93.61%
# [Linear 75] train: loss=0.1219, acc=95.75% | val: loss=0.2119, acc=93.39%
# [Linear 76] train: loss=0.1165, acc=95.90% | val: loss=0.2200, acc=93.56%
# [Linear 77] train: loss=0.1243, acc=95.73% | val: loss=0.2446, acc=92.85%
# [Linear 78] train: loss=0.1173, acc=95.92% | val: loss=0.2103, acc=93.57%
# [Linear 79] train: loss=0.1129, acc=95.99% | val: loss=0.2404, acc=92.74%
# [Linear 80] train: loss=0.1158, acc=96.03% | val: loss=0.2221, acc=93.54%
# [Linear 81] train: loss=0.1227, acc=95.55% | val: loss=0.2343, acc=92.94%
# [Linear 82] train: loss=0.1185, acc=95.83% | val: loss=0.2523, acc=92.72%
# [Linear 83] train: loss=0.1225, acc=95.77% | val: loss=0.2117, acc=93.30%
# [Linear 84] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 84] train: loss=0.1104, acc=96.15% | val: loss=0.1907, acc=94.11%
# [Linear 85] train: loss=0.1183, acc=95.74% | val: loss=0.2007, acc=93.69%
# [Linear 86] train: loss=0.1144, acc=96.04% | val: loss=0.2314, acc=92.89%
# [Linear 87] train: loss=0.1161, acc=96.07% | val: loss=0.2461, acc=93.17%
# [Linear 88] train: loss=0.1202, acc=95.89% | val: loss=0.2670, acc=92.46%
# [Linear 89] train: loss=0.1187, acc=95.85% | val: loss=0.2152, acc=93.28%
# [Linear 90] train: loss=0.1041, acc=96.39% | val: loss=0.2252, acc=93.33%
# [Linear 91] train: loss=0.1119, acc=96.02% | val: loss=0.2287, acc=93.43%
# [Linear 92] train: loss=0.1023, acc=96.32% | val: loss=0.2012, acc=93.94%
# [Linear 93] train: loss=0.1046, acc=96.34% | val: loss=0.2166, acc=93.85%
# [Linear 94] train: loss=0.1055, acc=96.13% | val: loss=0.2464, acc=92.28%
# [Linear 95] train: loss=0.1083, acc=96.06% | val: loss=0.2046, acc=93.85%
# [Linear 96] ✅ Saved best head -> /kaggle/working/byol_ckpts/byol_linear_head_best.pth
# [Linear 96] train: loss=0.1071, acc=96.11% | val: loss=0.1913, acc=94.26%
# [Linear 97] train: loss=0.0998, acc=96.37% | val: loss=0.2146, acc=93.65%
# [Linear 98] train: loss=0.0999, acc=96.45% | val: loss=0.2039, acc=93.65%
# [Linear 99] train: loss=0.1117, acc=96.23% | val: loss=0.2080, acc=93.93%
# [Linear 100] train: loss=0.1102, acc=95.92% | val: loss=0.2307, acc=93.57%
# [Linear 101] train: loss=0.1075, acc=96.10% | val: loss=0.2253, acc=93.44%
# [Linear 102] train: loss=0.0967, acc=96.46% | val: loss=0.2221, acc=93.35%
# [Linear 103] train: loss=0.0974, acc=96.68% | val: loss=0.2382, acc=93.00%
# [Linear 104] train: loss=0.1016, acc=96.27% | val: loss=0.2053, acc=93.89%
# [Linear 105] train: loss=0.0979, acc=96.50% | val: loss=0.2282, acc=93.30%
# [Linear 106] train: loss=0.0992, acc=96.56% | val: loss=0.2156, acc=93.61%
# [Linear 107] train: loss=0.0908, acc=96.81% | val: loss=0.2646, acc=92.85%
# [Linear 108] train: loss=0.1046, acc=96.32% | val: loss=0.2011, acc=94.04%
# [Linear 109] train: loss=0.0969, acc=96.49% | val: loss=0.2519, acc=92.57%
# [Linear 110] train: loss=0.0988, acc=96.37% | val: loss=0.2148, acc=93.76%
# [Linear 111] train: loss=0.0902, acc=96.85% | val: loss=0.1990, acc=93.96%
# [Linear 112] train: loss=0.0931, acc=96.76% | val: loss=0.2162, acc=93.52%
# [Linear 113] train: loss=0.0995, acc=96.40% | val: loss=0.2180, acc=93.69%
# [Linear 114] train: loss=0.0931, acc=96.69% | val: loss=0.2307, acc=93.19%
# [Linear 115] train: loss=0.0884, acc=96.94% | val: loss=0.2050, acc=93.83%
# [Linear 116] train: loss=0.0929, acc=96.79% | val: loss=0.2318, acc=93.20%
# [Linear 117] train: loss=0.0955, acc=96.54% | val: loss=0.2009, acc=93.91%
# [Linear 118] train: loss=0.0895, acc=96.74% | val: loss=0.2092, acc=93.69%
# [Linear 119] train: loss=0.0932, acc=96.63% | val: loss=0.2113, acc=93.78%
# [Linear 120] train: loss=0.1040, acc=96.33% | val: loss=0.2508, acc=92.31%
# [Linear 121] train: loss=0.0906, acc=96.76% | val: loss=0.2115, acc=93.54%
# [Linear 122] train: loss=0.0874, acc=96.92% | val: loss=0.2484, acc=92.69%
# [Linear 123] train: loss=0.0868, acc=96.90% | val: loss=0.2195, acc=93.33%
# [Linear 124] train: loss=0.0899, acc=96.71% | val: loss=0.2747, acc=92.17%
# [Linear 125] train: loss=0.0933, acc=96.61% | val: loss=0.2050, acc=93.65%
# [Linear 126] train: loss=0.0892, acc=96.84% | val: loss=0.2092, acc=93.61%
# [Linear 127] train: loss=0.0849, acc=97.04% | val: loss=0.2239, acc=93.54%
# [Linear 128] train: loss=0.0927, acc=96.65% | val: loss=0.2431, acc=93.17%
# [Linear 129] train: loss=0.0952, acc=96.62% | val: loss=0.2097, acc=93.81%
# [Linear 130] train: loss=0.0863, acc=96.93% | val: loss=0.2683, acc=92.54%
# [Linear 131] train: loss=0.1014, acc=96.31% | val: loss=0.2230, acc=93.28%
# [Linear 132] train: loss=0.0840, acc=97.04% | val: loss=0.2352, acc=93.43%
# [Linear 133] train: loss=0.0880, acc=96.80% | val: loss=0.2126, acc=93.15%
# [Linear 134] train: loss=0.0833, acc=96.97% | val: loss=0.2066, acc=93.65%
# [Linear 135] train: loss=0.0867, acc=96.87% | val: loss=0.2460, acc=92.76%
# [Linear 136] train: loss=0.0909, acc=96.76% | val: loss=0.2513, acc=93.04%
# [Linear 137] train: loss=0.0853, acc=96.93% | val: loss=0.2096, acc=93.93%
# [Linear 138] train: loss=0.0786, acc=97.15% | val: loss=0.2158, acc=93.78%
# [Linear 139] train: loss=0.0840, acc=97.17% | val: loss=0.2292, acc=93.31%
# [Linear 140] train: loss=0.0838, acc=96.94% | val: loss=0.2305, acc=93.37%
# [Linear 141] train: loss=0.0947, acc=96.57% | val: loss=0.2016, acc=93.85%
# [Linear 142] train: loss=0.0860, acc=97.06% | val: loss=0.2185, acc=93.54%
# [Linear 143] train: loss=0.0903, acc=96.72% | val: loss=0.2281, acc=93.65%
# [Linear 144] train: loss=0.0816, acc=97.13% | val: loss=0.2254, acc=93.48%
# [Linear 145] train: loss=0.0874, acc=96.91% | val: loss=0.2624, acc=93.15%
# [Linear 146] train: loss=0.0842, acc=96.97% | val: loss=0.2526, acc=92.78%
# [Linear 147] train: loss=0.0857, acc=96.84% | val: loss=0.2081, acc=93.59%
# [Linear 148] train: loss=0.0832, acc=97.11% | val: loss=0.2375, acc=93.31%
# [Linear 149] train: loss=0.0758, acc=97.28% | val: loss=0.2141, acc=93.65%
# [Linear 150] train: loss=0.0842, acc=96.97% | val: loss=0.2565, acc=92.70%
# [Linear 151] train: loss=0.0787, acc=97.17% | val: loss=0.2351, acc=93.31%
# [Linear 152] train: loss=0.0791, acc=97.13% | val: loss=0.2199, acc=93.70%
# [Linear 153] train: loss=0.0738, acc=97.49% | val: loss=0.2110, acc=93.80%
# [Linear 154] train: loss=0.0802, acc=97.15% | val: loss=0.2058, acc=94.04%
# [Linear 155] train: loss=0.0786, acc=97.37% | val: loss=0.2977, acc=91.50%
# [Linear 156] train: loss=0.0780, acc=97.08% | val: loss=0.2825, acc=92.46%
# [Linear 157] train: loss=0.0783, acc=97.18% | val: loss=0.2431, acc=93.22%
# [Linear 158] train: loss=0.0717, acc=97.36% | val: loss=0.2316, acc=93.41%
# [Linear 159] train: loss=0.0807, acc=97.21% | val: loss=0.2099, acc=93.80%
# [Linear 160] train: loss=0.0728, acc=97.40% | val: loss=0.2174, acc=93.28%
# [Linear 161] train: loss=0.0742, acc=97.35% | val: loss=0.2458, acc=92.87%
# [Linear 162] train: loss=0.0713, acc=97.33% | val: loss=0.2082, acc=93.81%
# [Linear 163] train: loss=0.0727, acc=97.43% | val: loss=0.2209, acc=93.76%
# [Linear 164] train: loss=0.0760, acc=97.45% | val: loss=0.2564, acc=93.00%
# [Linear 165] train: loss=0.0784, acc=97.10% | val: loss=0.2151, acc=93.72%
# [Linear 166] train: loss=0.0773, acc=97.24% | val: loss=0.2094, acc=94.09%
# [Linear 167] train: loss=0.0675, acc=97.51% | val: loss=0.2055, acc=94.04%
# [Linear 168] train: loss=0.0671, acc=97.75% | val: loss=0.2337, acc=93.09%
# [Linear 169] train: loss=0.0654, acc=97.68% | val: loss=0.2472, acc=92.59%
# [Linear 170] train: loss=0.0777, acc=97.17% | val: loss=0.2197, acc=93.61%
# [Linear 171] train: loss=0.0718, acc=97.49% | val: loss=0.2284, acc=93.46%
# [Linear 172] train: loss=0.0773, acc=97.27% | val: loss=0.2570, acc=92.76%
# [Linear 173] train: loss=0.0675, acc=97.62% | val: loss=0.2238, acc=93.61%
# [Linear 174] train: loss=0.0658, acc=97.74% | val: loss=0.2200, acc=93.74%
# [Linear 175] train: loss=0.0734, acc=97.40% | val: loss=0.2808, acc=92.69%
# [Linear 176] train: loss=0.0737, acc=97.40% | val: loss=0.3152, acc=91.89%
# [Linear 177] train: loss=0.0692, acc=97.56% | val: loss=0.2372, acc=93.15%
# [Linear 178] train: loss=0.0705, acc=97.51% | val: loss=0.2430, acc=92.81%
# [Linear 179] train: loss=0.0714, acc=97.46% | val: loss=0.2192, acc=93.81%
# [Linear 180] train: loss=0.0771, acc=97.21% | val: loss=0.2361, acc=93.46%
# [Linear 181] train: loss=0.0668, acc=97.69% | val: loss=0.2243, acc=93.63%
# [Linear 182] train: loss=0.0603, acc=97.94% | val: loss=0.2316, acc=93.72%
# [Linear 183] train: loss=0.0669, acc=97.48% | val: loss=0.2320, acc=93.28%
# [Linear 184] train: loss=0.0643, acc=97.74% | val: loss=0.2452, acc=93.35%
# [Linear 185] train: loss=0.0751, acc=97.35% | val: loss=0.2443, acc=93.44%
# [Linear 186] train: loss=0.0709, acc=97.61% | val: loss=0.2248, acc=93.37%
# [Linear 187] train: loss=0.0687, acc=97.61% | val: loss=0.2162, acc=93.69%
# [Linear 188] train: loss=0.0656, acc=97.63% | val: loss=0.2192, acc=93.93%
# [Linear 189] train: loss=0.0630, acc=97.77% | val: loss=0.2276, acc=93.69%
# [Linear 190] train: loss=0.0670, acc=97.65% | val: loss=0.2659, acc=92.63%
# [Linear 191] train: loss=0.0702, acc=97.38% | val: loss=0.2368, acc=93.52%
# [Linear 192] train: loss=0.0683, acc=97.56% | val: loss=0.2228, acc=93.91%
# [Linear 193] train: loss=0.0657, acc=97.65% | val: loss=0.2388, acc=93.39%
# [Linear 194] train: loss=0.0642, acc=97.73% | val: loss=0.2466, acc=93.04%
# [Linear 195] train: loss=0.0613, acc=97.90% | val: loss=0.2197, acc=93.69%
# [Linear 196] train: loss=0.0604, acc=97.87% | val: loss=0.2503, acc=93.24%
# [Linear 197] train: loss=0.0578, acc=98.04% | val: loss=0.2262, acc=93.74%
# [Linear 198] train: loss=0.0677, acc=97.59% | val: loss=0.2135, acc=93.85%
# [Linear 199] train: loss=0.0643, acc=97.63% | val: loss=0.2398, acc=93.54%
# [Linear 200] train: loss=0.0626, acc=97.87% | val: loss=0.2231, acc=93.69%
# [Linear 201] train: loss=0.0645, acc=97.68% | val: loss=0.2484, acc=93.00%
# [Linear 202] train: loss=0.0601, acc=97.96% | val: loss=0.2226, acc=93.26%
# [Linear 203] train: loss=0.0566, acc=98.01% | val: loss=0.2223, acc=93.89%
# [Linear 204] train: loss=0.0596, acc=97.86% | val: loss=0.2522, acc=93.43%
# [Linear 205] train: loss=0.0598, acc=97.94% | val: loss=0.2317, acc=93.57%
# [Linear 206] train: loss=0.0652, acc=97.62% | val: loss=0.2415, acc=93.67%
# [Linear 207] train: loss=0.0676, acc=97.61% | val: loss=0.2263, acc=93.81%
# [Linear 208] train: loss=0.0597, acc=97.89% | val: loss=0.2144, acc=94.09%
# [Linear 209] train: loss=0.0617, acc=97.77% | val: loss=0.2293, acc=93.30%
# [Linear 210] train: loss=0.0561, acc=98.04% | val: loss=0.2154, acc=94.02%
# [Linear 211] train: loss=0.0593, acc=97.95% | val: loss=0.2476, acc=93.11%
# [Linear 212] train: loss=0.0589, acc=98.01% | val: loss=0.2103, acc=94.09%
# [Linear 213] train: loss=0.0607, acc=97.79% | val: loss=0.2242, acc=93.78%
# [Linear 214] train: loss=0.0611, acc=97.83% | val: loss=0.2345, acc=93.33%
# [Linear 215] train: loss=0.0656, acc=97.66% | val: loss=0.2701, acc=93.11%
# [Linear 216] train: loss=0.0633, acc=97.78% | val: loss=0.2387, acc=93.00%
# [Linear 217] train: loss=0.0585, acc=97.93% | val: loss=0.2285, acc=93.31%
# [Linear 218] train: loss=0.0543, acc=98.08% | val: loss=0.2142, acc=93.93%
# [Linear 219] train: loss=0.0586, acc=97.96% | val: loss=0.2634, acc=93.02%
# [Linear 220] train: loss=0.0662, acc=97.73% | val: loss=0.2617, acc=93.56%
# [Linear 221] train: loss=0.0673, acc=97.49% | val: loss=0.2471, acc=93.56%
# [Linear 222] train: loss=0.0548, acc=97.96% | val: loss=0.2453, acc=93.35%
# [Linear 223] train: loss=0.0547, acc=98.17% | val: loss=0.2316, acc=93.37%
# [Linear 224] train: loss=0.0574, acc=98.02% | val: loss=0.2703, acc=92.70%
# [Linear 225] train: loss=0.0655, acc=97.71% | val: loss=0.3297, acc=92.13%
# [Linear 226] train: loss=0.0599, acc=97.85% | val: loss=0.2386, acc=93.59%
# [Linear 227] train: loss=0.0605, acc=97.86% | val: loss=0.3217, acc=91.89%
# [Linear 228] train: loss=0.0569, acc=98.04% | val: loss=0.2167, acc=93.94%
# [Linear 229] train: loss=0.0569, acc=97.89% | val: loss=0.2371, acc=93.85%
# [Linear 230] train: loss=0.0513, acc=98.29% | val: loss=0.2288, acc=93.69%
# [Linear 231] train: loss=0.0571, acc=98.02% | val: loss=0.2482, acc=93.13%
# [Linear 232] train: loss=0.0539, acc=98.15% | val: loss=0.2334, acc=93.48%
# [Linear 233] train: loss=0.0497, acc=98.33% | val: loss=0.2406, acc=93.54%
# [Linear 234] train: loss=0.0510, acc=98.23% | val: loss=0.2570, acc=93.22%
# [Linear 235] train: loss=0.0611, acc=97.88% | val: loss=0.2585, acc=93.04%
# [Linear 236] train: loss=0.0513, acc=98.16% | val: loss=0.2186, acc=93.91%
# [Linear 237] train: loss=0.0596, acc=97.94% | val: loss=0.2504, acc=93.39%
# [Linear 238] train: loss=0.0521, acc=98.22% | val: loss=0.2415, acc=93.26%
# [Linear 239] train: loss=0.0494, acc=98.39% | val: loss=0.2519, acc=93.33%
# [Linear 240] train: loss=0.0597, acc=97.91% | val: loss=0.2672, acc=93.31%
# [Linear 241] train: loss=0.0531, acc=98.12% | val: loss=0.2351, acc=93.76%
# [Linear 242] train: loss=0.0607, acc=97.85% | val: loss=0.2391, acc=93.69%
# [Linear 243] train: loss=0.0486, acc=98.40% | val: loss=0.2278, acc=93.61%
# [Linear 244] train: loss=0.0514, acc=98.26% | val: loss=0.2471, acc=93.28%
# [Linear 245] train: loss=0.0467, acc=98.36% | val: loss=0.2386, acc=93.26%
# [Linear 246] train: loss=0.0599, acc=97.82% | val: loss=0.2384, acc=93.46%
# [Linear 247] train: loss=0.0502, acc=98.23% | val: loss=0.2291, acc=93.96%
# [Linear 248] train: loss=0.0479, acc=98.33% | val: loss=0.2220, acc=94.02%
# [Linear 249] train: loss=0.0503, acc=98.33% | val: loss=0.2582, acc=93.37%
# [Linear 250] train: loss=0.0544, acc=98.03% | val: loss=0.2305, acc=93.89%
# [Linear 251] train: loss=0.0477, acc=98.39% | val: loss=0.2703, acc=93.00%
# [Linear 252] train: loss=0.0536, acc=97.99% | val: loss=0.2419, acc=93.87%
# [Linear 253] train: loss=0.0607, acc=97.90% | val: loss=0.2900, acc=92.19%
# [Linear 254] train: loss=0.0517, acc=98.17% | val: loss=0.2795, acc=92.72%
# [Linear 255] train: loss=0.0561, acc=97.87% | val: loss=0.2206, acc=93.87%
# [Linear 256] train: loss=0.0473, acc=98.42% | val: loss=0.2407, acc=93.83%
# [Linear 257] train: loss=0.0412, acc=98.72% | val: loss=0.2360, acc=93.41%
# [Linear 258] train: loss=0.0510, acc=98.26% | val: loss=0.2559, acc=93.07%
# [Linear 259] train: loss=0.0481, acc=98.23% | val: loss=0.2719, acc=92.69%
# [Linear 260] train: loss=0.0481, acc=98.35% | val: loss=0.2282, acc=93.78%
# [Linear 261] train: loss=0.0454, acc=98.43% | val: loss=0.2469, acc=93.24%
# [Linear 262] train: loss=0.0413, acc=98.64% | val: loss=0.2945, acc=92.61%
# [Linear 263] train: loss=0.0539, acc=98.21% | val: loss=0.2313, acc=93.70%
# [Linear 264] train: loss=0.0472, acc=98.37% | val: loss=0.2392, acc=93.81%
# [Linear 265] train: loss=0.0437, acc=98.52% | val: loss=0.2268, acc=93.81%
# [Linear 266] train: loss=0.0494, acc=98.20% | val: loss=0.2432, acc=93.67%
# [Linear 267] train: loss=0.0524, acc=98.24% | val: loss=0.2439, acc=93.37%
# [Linear 268] train: loss=0.0430, acc=98.60% | val: loss=0.2623, acc=93.22%
# [Linear 269] train: loss=0.0486, acc=98.28% | val: loss=0.2344, acc=94.02%
# [Linear 270] train: loss=0.0471, acc=98.39% | val: loss=0.2333, acc=93.89%
# [Linear 271] train: loss=0.0473, acc=98.40% | val: loss=0.2652, acc=93.41%
# [Linear 272] train: loss=0.0469, acc=98.40% | val: loss=0.2670, acc=93.33%
# [Linear 273] train: loss=0.0537, acc=98.14% | val: loss=0.2413, acc=93.78%
# [Linear 274] train: loss=0.0442, acc=98.51% | val: loss=0.2730, acc=93.44%
# [Linear 275] train: loss=0.0439, acc=98.49% | val: loss=0.2435, acc=93.72%
# [Linear 276] train: loss=0.0507, acc=98.21% | val: loss=0.2345, acc=93.83%
# [Linear 277] train: loss=0.0379, acc=98.83% | val: loss=0.2311, acc=93.80%
# [Linear 278] train: loss=0.0463, acc=98.40% | val: loss=0.2470, acc=93.39%
# [Linear 279] train: loss=0.0423, acc=98.50% | val: loss=0.3023, acc=92.72%
# [Linear 280] train: loss=0.0545, acc=98.18% | val: loss=0.2652, acc=93.26%
# [Linear 281] train: loss=0.0475, acc=98.42% | val: loss=0.2320, acc=93.52%
# [Linear 282] train: loss=0.0391, acc=98.75% | val: loss=0.2390, acc=93.59%
# [Linear 283] train: loss=0.0466, acc=98.44% | val: loss=0.2448, acc=93.59%
# [Linear 284] train: loss=0.0537, acc=98.22% | val: loss=0.2343, acc=94.07%
# [Linear 285] train: loss=0.0377, acc=98.76% | val: loss=0.2521, acc=93.09%
# [Linear 286] train: loss=0.0435, acc=98.49% | val: loss=0.2643, acc=93.24%
# [Linear 287] train: loss=0.0562, acc=98.01% | val: loss=0.2391, acc=93.52%
# [Linear 288] train: loss=0.0371, acc=98.78% | val: loss=0.3037, acc=92.11%
# [Linear 289] train: loss=0.0408, acc=98.65% | val: loss=0.2608, acc=93.24%
# [Linear 290] train: loss=0.0409, acc=98.69% | val: loss=0.2677, acc=93.15%
# [Linear 291] train: loss=0.0449, acc=98.47% | val: loss=0.2464, acc=93.46%
# [Linear 292] train: loss=0.0393, acc=98.70% | val: loss=0.2678, acc=93.13%
# [Linear 293] train: loss=0.0420, acc=98.51% | val: loss=0.2391, acc=93.85%
# [Linear 294] train: loss=0.0433, acc=98.58% | val: loss=0.2378, acc=94.19%
# [Linear 295] train: loss=0.0403, acc=98.61% | val: loss=0.2456, acc=93.33%
# [Linear 296] train: loss=0.0432, acc=98.53% | val: loss=0.2704, acc=93.59%
# [Linear 297] train: loss=0.0494, acc=98.39% | val: loss=0.2410, acc=93.76%
# [Linear 298] train: loss=0.0372, acc=98.78% | val: loss=0.2428, acc=93.65%
# [Linear 299] train: loss=0.0370, acc=98.80% | val: loss=0.2670, acc=93.00%
# [Linear 300] train: loss=0.0363, acc=98.87% | val: loss=0.2644, acc=93.41%

# %%
# --- Accuracy curve (%)
plt.figure(figsize=(7,4))
plt.plot(lin_hist["epoch"], lin_hist["train_acc"], label="Train Acc (%)")
plt.plot(lin_hist["epoch"], lin_hist["val_acc"],   label="Val Acc (%)")
plt.xlabel("Epoch"); plt.ylabel("Accuracy (%)")
plt.title("Linear Evaluation — Accuracy")
plt.legend(); 
plt.tight_layout()
plt.show()

# --- Loss curve
plt.figure(figsize=(7,4))
plt.plot(lin_hist["epoch"], lin_hist["train_loss"], label="Train Loss")
plt.plot(lin_hist["epoch"], lin_hist["val_loss"],   label="Val Loss")
plt.xlabel("Epoch"); plt.ylabel("Loss")
plt.title("Linear Evaluation — Loss")
plt.legend(); 
plt.tight_layout()
plt.show()

# %%
# ---- evaluate on TEST ----
all_y, all_pred = [], []
crit = nn.CrossEntropyLoss()
test_loss, total = 0.0, 0

with torch.no_grad():
    for x, y in test_cls_loader:
        x = x.to(DEVICE, non_blocking=True)
        y = y.to(DEVICE, non_blocking=True)

        feats = encoder(x)
        logits = head(feats)  # Use `head` instead of `lin_model`
        loss = crit(logits, y)

        pred = torch.argmax(logits, dim=1).cpu().numpy().tolist()
        all_pred.extend(pred)
        all_y.extend(y.cpu().numpy().tolist())

        test_loss += loss.item() * x.size(0)
        total += y.size(0)

acc = accuracy_score(all_y, all_pred)
test_loss = test_loss / max(1, total)

print(f"Test Accuracy: {acc*100:.2f}%")
print(classification_report(all_y, all_pred, digits=4, zero_division=0))  # ✅ warning fixed
# Out:
# Test Accuracy: 94.74%
#               precision    recall  f1-score   support
#
#            0     0.9467    0.9467    0.9467       300
#            1     0.9966    0.9833    0.9899       300
#            2     0.8720    0.9533    0.9108       300
#            3     0.8429    0.9440    0.8906       250
#            4     0.9800    0.9800    0.9800       250
#            5     0.9356    0.9450    0.9403       200
#            6     0.9636    0.8480    0.9021       250
#            7     0.9901    0.9967    0.9934       300
#            8     0.9640    0.8560    0.9068       250
#            9     0.9933    0.9933    0.9933       300
#
#     accuracy                         0.9474      2700
#    macro avg     0.9485    0.9446    0.9454      2700
# weighted avg     0.9498    0.9474    0.9475      2700

# %%
@torch.no_grad()
def extract_features(encoder, loader, device=None):
    """Freeze encoder → collect features & labels from a loader."""
    if device is None:
        device = next(encoder.parameters()).device
    encoder.eval()
    feats, labels = [], []
    for x, y in loader:
        x = x.to(device, non_blocking=True)
        z = encoder(x)              # shape: [B, D]
        z = z.detach().cpu().numpy()
        y = y.detach().cpu().numpy()
        feats.append(z); labels.append(y)
    feats  = np.concatenate(feats, axis=0)
    labels = np.concatenate(labels, axis=0)
    return feats, labels

def silhouette_cosine(feats, labels):
    """Silhouette score with cosine distance; safe when a single class present."""
    if len(np.unique(labels)) < 2 or len(labels) < 3:
        return float("nan")
    # sklearn expects a similarity converted to distance for 'cosine'
    return silhouette_score(feats, labels, metric="cosine")

def tsne_plot_3d(feats, labels, title,
                 perplexity=30, max_points=5000, seed=42, save_html=None):
    """3D t-SNE (Plotly) — caps points, auto-safe perplexity, saves HTML if path given."""
    # cap points for speed
    if feats.shape[0] > max_points:
        idx = np.random.RandomState(seed).choice(feats.shape[0], size=max_points, replace=False)
        feats = feats[idx]; labels = labels[idx]

    # t-SNE rule: perplexity < n_samples
    n = feats.shape[0]
    perp = min(perplexity, max(5, n // 3))  # keep within a safe range

    emb = TSNE(
        n_components=3, perplexity=perp, init="pca",
        learning_rate="auto", random_state=seed, n_iter=1000, verbose=0
    ).fit_transform(feats)

    fig = px.scatter_3d(
        x=emb[:,0], y=emb[:,1], z=emb[:,2],
        color=labels.astype(str), title=title, height=700, width=900
    )
    fig.update_traces(marker=dict(size=3))
    if save_html:
        fig.write_html(save_html)
        print(f"Saved interactive HTML to: {save_html}")
    fig.show()

# %%
# TRAIN set clusters (frozen encoder)
train_feats, train_labels = extract_features(encoder, train_cls_loader, device=DEVICE)
print(f"Training silhouette score (cosine): {silhouette_cosine(train_feats, train_labels):.4f}")

tsne_plot_3d(
    train_feats, train_labels,
    title="3D t-SNE (train features)",
    perplexity=30, max_points=5000, seed=42,
    save_html="/kaggle/working/tsne3d_train.html"
)
# Out:
# Training silhouette score (cosine): 0.3275
# Saved interactive HTML to: /kaggle/working/tsne3d_train.html
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fdc8deb0-c111-42a4-aa54-b8e4c97f12d4" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdc8deb0-c111-42a4-aa54-b8e4c97f12d4")) {                    Plotly.newPlot(                        "fdc8deb0-c111-42a4-aa54-b8e4c97f12d4",                        [{"hovertemplate":"color=8\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"8","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"8","scene":"scene","showlegend":true,"x":[0.4344607,-0.6802617,8.621114,-2.4154184,11.663465,6.937595,-3.3581984,9.767647,6.0395346,2.554112,-2.6600964,8.965482,7.0815086,2.3446348,10.357792,5.0217924,0.24939832,0.81561613,5.555969,4.695086,11.6647005,-1.1472595,-0.93407416,-0.87045723,6.5796323,9.715326,2.83692,0.07643165,10.187137,7.4926023,9.867013,-3.6953392,6.528036,11.070676,7.5104337,4.189185,9.695235,6.2245793,8.928647,12.286942,8.167535,8.385542,-3.3664186,0.039003264,-0.020420568,11.822136,7.3070717,5.6989427,6.9598036,8.628084,11.605669,5.365027,9.305207,-2.4218032,11.015787,1.4666655,7.6198134,7.385123,11.538265,0.74657017,5.9652367,0.48695305,6.0785775,5.240887,-2.902805,11.18642,1.8306152,-5.7868705,9.213786,2.0809014,6.858746,9.274088,2.262552,8.618181,7.771711,-7.0760217,-1.1525706,9.177101,8.3326025,5.2691293,9.815797,8.732535,0.26749843,7.1779833,10.820051,6.575127,7.7234926,4.086593,-2.9233325,6.305053,5.9338884,7.063874,-3.1843097,10.798064,-0.48385376,-2.175229,8.526106,9.877062,11.6654005,11.61051,10.01427,4.8842764,11.848549,-5.3614798,5.760054,5.9070063,2.4857354,4.3209333,1.5584359,2.5937474,-1.6443042,11.76549,6.871813,6.3806047,10.934591,8.69458,6.4979806,4.9749594,6.500766,6.371636,2.964193,3.1858978,6.596187,0.7192175,2.363394,8.666733,10.097407,10.027887,3.2749,9.819315,11.5375,7.254136,10.141731,11.561986,9.3967705,6.11742,9.917349,11.637221,10.785928,4.547923,6.1904273,9.941179,1.7590955,10.792365,1.493567,1.516602,-0.33120218,3.0399742,11.02963,-0.31313118,7.7655654,-0.16655591,3.841911,1.4597664,-0.6232435,11.861432,11.397729,5.04568,12.310003,6.4669385,-3.2321951,-2.8434708,2.3669164,9.82145,0.7268388,1.4547843,3.1343517,-5.4776087,10.026654,7.2210374,9.939371,11.510804,-0.9627641,10.985531,6.8229785,5.218296,2.8805728,-1.3403119,2.4632998,10.614375,7.4230876,11.648748,4.94974,4.515106,1.749035,6.2574296,7.2087135,7.6060567,4.0851173,1.4042152,-3.485205,6.7350698,0.6388204,-0.38566887,7.915859,2.3441322,11.58344,6.8023996,-1.8548459,7.6514134,-0.3763234,8.308893,9.699833,11.246703,0.63315624,11.833137,4.371285,0.8634778,5.7039413,6.633043,11.33114,1.3883694,6.387779,0.5685539,0.40601537,7.2909565,6.505658,-0.06468907,5.2070065,11.75056,3.8400486,-1.3966604,9.735561,7.0224195,7.917628,3.8839388,11.523355,-3.3138745,6.256225,11.458987,10.090204,4.621487,-0.13856122,7.9202724,8.431901,9.8354225,3.7942324,4.1607018,7.0177503,1.3381822,7.817754,-2.5909228,8.025962,-0.24613126,8.243452,9.819419,10.569552,4.0696363,2.5131466,8.214799,-1.6533041,8.10025,9.332949,1.6023864,-1.9765259,1.0764248,11.445595,9.23257,11.161778,12.302729,-0.23826599,8.323146,11.506199,2.8637404,7.0890965,5.8806973,8.318632,4.9389567,6.4718337,-1.5623661,4.751751,3.9008026,9.025324,5.007001,8.609517,9.679606,1.3924725,9.533729,12.714711,3.9087403,11.165174,-2.0239587,0.46772206,4.139123,-1.7343659,6.404604,6.8858447,5.7294374,-2.986887,0.673334,3.301373,1.1783987,8.163816,7.719423,8.849831,2.1368814,4.614961,0.7698318,3.6657436,7.068844,-0.26821446,9.586389,7.8768024,11.797197,9.3663645,3.4282453,11.453623,0.6302246,9.63403,8.4034605,6.7609267,-2.0189734,12.14298,6.656183,5.016672,-0.26139477,11.83447,2.8640234,7.3592043,-1.7634531,8.27295,2.9399264, ...

# %%
# TEST set clusters (frozen encoder)
test_feats, test_labels = extract_features(encoder, test_cls_loader, device=DEVICE)
print(f"Test silhouette score (cosine): {silhouette_cosine(test_feats, test_labels):.4f}")

tsne_plot_3d(
    test_feats, test_labels,
    title="3D t-SNE (test features)",
    perplexity=30, max_points=5000, seed=42,
    save_html="/kaggle/working/tsne3d_test.html"
)
# Out:
# Test silhouette score (cosine): 0.3490
# Saved interactive HTML to: /kaggle/working/tsne3d_test.html
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c7f2413e-dda0-4bac-a9e8-56d1038b8e18" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7f2413e-dda0-4bac-a9e8-56d1038b8e18")) {                    Plotly.newPlot(                        "c7f2413e-dda0-4bac-a9e8-56d1038b8e18",                        [{"hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":[-8.860854,-10.808858,-10.472904,-10.65962,-4.5077796,-7.0615625,-7.3121343,-6.362068,-2.384386,-1.0147688,-7.0232396,-3.9934227,-8.305648,-1.7163278,-6.697518,-9.38296,-11.099487,-2.6258597,-2.2233205,-2.5795307,-8.136362,-3.7764547,-7.1296144,-6.356121,-1.3438605,5.0313673,-2.1766455,-6.5831323,-7.8625326,-1.2582457,-1.0764703,-7.390952,-4.817632,-3.8838048,-8.809593,-1.9076073,-6.3748374,-5.2306576,-10.246837,-6.1166644,-7.721407,1.7161599,-3.7748375,-5.6632667,-2.8618817,-7.168566,-2.8758824,-6.4991503,-11.105227,-1.416406,-1.2836995,-2.770819,-3.9614456,-8.986061,-9.794622,8.055719,-8.149292,-2.2731795,-4.5770674,-2.737213,-7.966592,-2.1867762,-4.566908,-10.470482,-9.488607,-6.9948683,-1.6204286,-6.7699456,-7.655941,-10.494363,-6.933831,-7.2826104,-6.5117626,-4.623714,-3.1531186,-3.438125,-6.7012115,-9.163876,-5.1095495,-3.9867241,-10.088897,-4.4141984,-5.654596,-5.469826,-3.6874387,-2.6236644,-1.5112954,-5.396061,-6.649509,-2.8664238,-3.4166653,-9.279862,-2.9246788,-5.0533123,-7.226217,-6.3757863,-4.5047064,-5.7671328,-7.5379,-3.8208141,-8.04371,-6.1660914,-2.9618742,-2.5381284,-3.9324455,-7.3362784,-3.5988047,-10.788758,-9.035125,-7.74026,-1.7629975,-9.158957,-3.4319422,-3.9650388,-3.773458,-4.4873476,-7.3578634,-7.5253906,-4.66484,-7.2675967,-0.6137211,-7.1750865,-1.6608062,-1.9091071,3.1257536,-1.5214607,-3.0932448,-10.136137,-10.221633,-2.8082347,-2.4722676,-2.633888,-6.6750455,-8.993876,-2.80477,-7.232937,-7.4985995,-5.313486,-4.3404837,-2.2307045,-8.314133,-1.4964443,-3.377282,-7.5139513,-1.8091437,4.710991,-8.726045,-11.100151,-5.5324106,-6.2892,-7.59321,-5.3333364,-2.0416205,-6.5855756,-2.4017894,-7.372889,-7.690479,-10.188071,3.058849,-10.12398,-3.135758,-1.932722,-8.095227,-1.2130136,-2.1536422,-4.1247582,-7.894111,-2.9370956,-7.6050124,-2.262192,-7.060505,-11.167879,-1.3731918,-1.991608,-1.9510587,-4.935618,-9.331709,-9.64634,5.373778,-10.050589,-6.873666,-1.877135,-3.5725148,-7.427727,-4.229856,-3.4613347,-2.8933482,-3.867043,-5.935298,2.563022,-2.7609658,-2.992332,-1.3908671,-5.6452837,-2.3484473,-6.1178637,-7.692867,-6.2657094,-3.3223772,-1.9259522,-4.1344995,-1.2284313,-2.6452687,-7.042401,-6.8502693,-6.602554,-4.1053896,-6.110955,-10.228762,-9.300587,-1.4765267,-2.8988767,-2.0748982,-3.3505404,-2.4974968,-10.901391,-7.0904794,-8.8431425,-4.835268,-10.34262,-1.3544431,-3.1447914,-4.12332,-3.660765,-6.7191496,-8.333409,-10.629026,-7.017303,-3.6962376,-5.2056084,-3.5406966,-3.3370585,-7.1537657,-7.815914,-8.268233,-2.5682516,-2.0255497,-11.174341,-3.3314147,-5.633785,-1.584501,-8.171534,-11.079013,-7.7789474,-8.867768,-9.789931,-7.3409753,-11.175982,-4.2821717,-10.1642885,-8.827152,-3.6055455,-8.867936,1.1070696,-3.58855,-5.6939635,-3.2074716,-3.1987514,-6.0958285,-9.214899,-10.232825,-1.6807032,-1.8863152,-2.9058723,-5.4702387,0.5209053,-5.995137,-8.054016,-6.265162,-8.975434,-7.2935653,-7.819482,-10.927308,-5.0790153,-4.2988286,-7.8301516,-2.7220097,-1.8810462,-2.2235212,-8.157593,-5.8942204,-8.76949,-3.49025,-10.316959,-7.6739597,-2.0715852,-2.8887389,-3.380674,-10.026183,-8.823862,-7.330198,-1.910094,-3.8549132,-6.0823283,-6.8426213,-2.1133525,3.6346784,-9.440943,-5.711133,-9.250226],"y": ...
